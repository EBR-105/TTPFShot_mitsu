# %%
import sys
print(sys.executable)
# Out:
# /workspace/miluser/Mitsuharu_2002/mitsuharu-12-02/bin/python

# %%
import torch
import sys
import os

print("Python:", sys.executable)
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
print("Realpath:", os.path.realpath(sys.executable))
print(torch.__file__)
print(torch.version.cuda)
print(torch.backends.cudnn.version())

device = torch.device("cuda:1")
# Out:
# Python: /workspace/miluser/Mitsuharu_2002/mitsuharu-12-02/bin/python
# CUDA available: True
# GPU name: NVIDIA RTX A6000
# Realpath: /opt/conda/bin/python3.11
# /workspace/miluser/Mitsuharu_2002/mitsuharu-12-02/lib/python3.11/site-packages/torch/__init__.py
# 12.4
# 90100

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import sys
print(sys.executable)

import os
os.environ["TRANSFORMERS_NO_TF"] = "1"
# Out:
# /workspace/miluser/Mitsuharu_2002/mitsuharu-12-02/bin/python

# %%
import os

import pprint
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings


from langchain_core.documents import Document


from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv("/workspace/miluser/Mitsuharu_2002/csv_data/TPPHunter_T_Again.csv")
df2 = pd.read_csv("/workspace/miluser/Mitsuharu_2002/csv_data/MITRE_ATTACKv15-1_TTP_Dataset.csv")

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Wed Dec 24 12:27:06 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.06              Driver Version: 555.42.06      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               Off |   00000000:03:00.0 Off |                  Off |
# | 30%   38C    P8             18W /  300W |      28MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000               Off |   00000000:21:00.0 Off |                  Off |
# | 30%   53C    P8             24W /  300W |    1234MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2302      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A   1024330      G   /usr/lib/xorg/Xorg                              4MiB |
# |    1   N/A  N/A      2302      G   /usr/lib/xorg/Xorg                             39MiB |
# |    1   N/A  N/A   1024330      G   /usr/lib/xorg/Xorg                             84MiB |
# |    1   N/A  N/A   1024459      G   /usr/bin/gnome-shell                           82MiB |
# |    1   N/A  N/A   2061370      C   ...aru_2002/mitsuharu-12-02/bin/python        832MiB |
# +-----------------------------------------------------------------------------------------+

# %%
df
# Out:
#         ID      Domain act_Technique ID                   act_TacticsName  \
# 0        1  Enterprise            T1543  Persistence:Privilege Escalation
# 1        2  Enterprise            T1562                   Defense Evasion
# 2        3  Enterprise            T1036                   Defense Evasion
# 3        4  Enterprise            T1036                   Defense Evasion
# 4        5  Enterprise            T1588              Resource Development
# ...    ...         ...              ...                               ...
# 8382  8383  Enterprise            T1573               Command and Control
# 8383  8384  Enterprise            T1041                      Exfiltration
# 8384  8385  Enterprise            T1083                         Discovery
# 8385  8386  Enterprise            T1057                         Discovery
# 8386  8387  Enterprise            T1087                         Discovery
#
#                                      act_Technique Name  \
# 0      Create or Modify System Process: Windows Service
# 1     Impair Defenses: Disable or Modify System Fire...
# 2              Masquerading: Masquerade Task or Service
# 3       Masquerading: Match Legitimate Name or Location
# 4                             Obtain Capabilities: Tool
# ...                                                 ...
# 8382          Encrypted Channel: Symmetric Cryptography
# 8383                       Exfiltration Over C2 Channel
# 8384                       File and Directory Discovery
# 8385                                  Process Discovery
# 8386                   Account Discovery: Email Account
#
#                                               Sentences test_or_train  \
# 0     Carbanak malware installs itself as a service ...         train
# 1     Carbanak may use netsh to add local firewall r...         train
# 2     Carbanak has copied legitimate service names t...         train
# 3     Carbanak has named malware "svchost.exe," whic...         train
# 4     Carbanak has obtained and used open-source too...         train
# ...                                                 ...           ...
# 8382  NETEAGLE will decrypt resources it downloads w...         train
# 8383  NETEAGLE is capable of reading files over the ...         train
# 8384  NETEAGLE allows adversaries to enumerate and m...         train
# 8385  NETEAGLE can send process listings over the C2...          test
# 8386  Ruler can be used to enumerate Exchange users ...          test
#
#      Predicted_ATT&CK ID_original Predicted_TacticsName
# 0                             NaN                   NaN
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# ...                           ...                   ...
# 8382                          NaN                   NaN
# 8383                          NaN                   NaN
# 8384                          NaN                   NaN
# 8385                        T1057          Exfiltration
# 8386                        T1087             Discovery
#
# [8387 rows x 9 columns]

# %%
df2
# Out:
#              Key                                              Value
# 0          T1094         Some Software variants use raw TCP for C2.
# 1          T1047  Software leverages WMI to enumerate anti-virus...
# 2      T1003.001  Software contains an implementation of Softwar...
# 3      T1614.001  Attacker has used implants to collect the syst...
# 4      T1587.001                     For Software modular backdoor.
# ...          ...                                                ...
# 19742      T1045  Most decompression techniques decompress the e...
# 19743  T1059.001  Software uses PowerShell to download and execu...
# 19744  T1059.003  Software can use `cmd.exe` to execute a create...
# 19745      T1112  Software has functionality to remove Registry ...
# 19746  T1204.001  Links may also lead users to download files th...
#
# [19747 rows x 2 columns]

# %%
len(set(df["act_Technique ID"]))
print(df.columns.tolist())
# Out:
# ['ID', 'Domain', 'act_Technique ID', 'act_TacticsName', 'act_Technique Name', 'Sentences', 'test_or_train', 'Predicted_ATT&CK ID_original', 'Predicted_TacticsName']

# %%
df = df[["ID", "test_or_train", "act_Technique ID", "act_Technique Name","act_TacticsName", "Sentences", "Predicted_TacticsName"]]

# %%
# train, test = train_test_split(df, test_size=0.2, random_state=0)
import pandas as pd
import numpy as np

# test_or_train が "train" の行だけ
train = df2

# test_or_train が "test" の行だけ
test = df[df["test_or_train"] == "test"].copy()

# %%
print(len(test))
print(len(train))
# Out:
# 1678
# 19747

# %%
test
# Out:
#         ID test_or_train act_Technique ID  \
# 14      15          test            T1005
# 20      21          test            T1588
# 22      23          test            T1566
# 23      24          test            T1057
# 29      30          test            T1204
# ...    ...           ...              ...
# 8368  8369          test            T1562
# 8369  8370          test            T1070
# 8381  8382          test            T1059
# 8385  8386          test            T1057
# 8386  8387          test            T1087
#
#                                      act_Technique Name       act_TacticsName  \
# 14                               Data from Local System            Collection
# 20                            Obtain Capabilities: Tool  Resource Development
# 22                   Phishing: Spearphishing Attachment        Initial Access
# 23                                    Process Discovery             Discovery
# 29                       User Execution: Malicious File             Execution
# ...                                                 ...                   ...
# 8368  Impair Defenses: Disable or Modify System Fire...       Defense Evasion
# 8369           Indicator Removal on Host: File Deletion       Defense Evasion
# 8381  Command and Scripting Interpreter: Windows Com...             Execution
# 8385                                  Process Discovery             Discovery
# 8386                   Account Discovery: Email Account             Discovery
#
#                                               Sentences Predicted_TacticsName
# 14    Frankenstein has enumerated hosts via Empire, ...             Discovery
# 20    Frankenstein has obtained and used Empire to d...             Execution
# 22    Frankenstein has used spearphishing emails to ...        Initial Access
# 23    Frankenstein has enumerated hosts, looking to ...             Discovery
# 29    Frankenstein has used trojanized Microsoft Wor...             Execution
# ...                                                 ...                   ...
# 8368  TYPEFRAME can open the Windows Firewall on the...       Defense Evasion
# 8369      TYPEFRAME can delete files off the system.[1]       Defense Evasion
# 8381  NETEAGLE allows adversaries to execute shell c...             Execution
# 8385  NETEAGLE can send process listings over the C2...          Exfiltration
# 8386  Ruler can be used to enumerate Exchange users ...             Discovery
#
# [1678 rows x 7 columns]

# %%
train
# Out:
#              Key                                              Value
# 0          T1094         Some Software variants use raw TCP for C2.
# 1          T1047  Software leverages WMI to enumerate anti-virus...
# 2      T1003.001  Software contains an implementation of Softwar...
# 3      T1614.001  Attacker has used implants to collect the syst...
# 4      T1587.001                     For Software modular backdoor.
# ...          ...                                                ...
# 19742      T1045  Most decompression techniques decompress the e...
# 19743  T1059.001  Software uses PowerShell to download and execu...
# 19744  T1059.003  Software can use `cmd.exe` to execute a create...
# 19745      T1112  Software has functionality to remove Registry ...
# 19746  T1204.001  Links may also lead users to download files th...
#
# [19747 rows x 2 columns]

# %%
import pandas as pd
import re

def base_tid(x: str) -> str | None:
    """T1587.001 -> T1587 / 'aaa T1587.001 bbb' -> T1587 / None -> None"""
    if pd.isna(x):
        return None
    s = str(x)
    m = re.search(r"(T\d{4})", s)   # まず親IDだけ拾う
    return m.group(1) if m else None

# train: columns = ["Key", "Value"]
# test : columns = ["act_Technique ID", "Sentences"]

# 1) testに出てくる親ID集合を作る
test_base_set = set(
    test["act_Technique ID"]
      .map(base_tid)
      .dropna()
      .unique()
)

# 2) train側も親IDを作って、含まれるものだけ残す
train2 = train.copy()
train2["_base"] = train2["Key"].map(base_tid)

train_filtered = train2[train2["_base"].isin(test_base_set)].drop(columns=["_base"])

print("before:", len(train), "after:", len(train_filtered))
# Out:
# before: 19747 after: 12660

# %%
# Key に "." が含まれる = サブテクニック とみなして除外
train_main = train[~train["Key"].astype(str).str.contains(r"\.", na=False)].reset_index(drop=True)

# %%
train_main
# Out:
#         Key                                              Value
# 0     T1094         Some Software variants use raw TCP for C2.
# 1     T1047  Software leverages WMI to enumerate anti-virus...
# 2     T1559  Software has the ability to move data between ...
# 3     T1518  Software can list PHP server configuration det...
# 4     T1134  Software has used <code>SeDebugPrivilege</code...
# ...     ...                                                ...
# 8842  T1033  During , threat actors enumerated sessions and...
# 8843  T1057  Software can enumerate the current process on ...
# 8844  T1038  Adversaries may also directly modify the way a...
# 8845  T1045  Most decompression techniques decompress the e...
# 8846  T1112  Software has functionality to remove Registry ...
#
# [8847 rows x 2 columns]

# %%
import pandas as pd
import re

def base_tid(x):
    if pd.isna(x):
        return None
    m = re.search(r"(T\d{4})", str(x))
    return m.group(1) if m else None

# train: ["Key","Value"]  (TechniqueIDはKeyに入ってる想定)
# test : ["act_Technique ID","Sentences"]

train2 = train.copy()
test2  = test.copy()

train2["_base"] = train2["Key"].map(base_tid)
test2["_base"]  = test2["act_Technique ID"].map(base_tid)

train_base_set = set(train2["_base"].dropna().unique())
test_base_set  = set(test2["_base"].dropna().unique())

missing_in_train = sorted(test_base_set - train_base_set)  # testにいるのにtrainにいない親ID
extra_in_train   = sorted(train_base_set - test_base_set)  # trainにいるのにtestにいない親ID（本来0のはず）

print("test parent IDs:", len(test_base_set))
print("train parent IDs:", len(train_base_set))
print("missing_in_train:", len(missing_in_train))
print("extra_in_train:", len(extra_in_train))

# 中身も見たい場合
print("missing_in_train examples:", missing_in_train[:30])
print("extra_in_train examples:", extra_in_train[:30])
# Out:
# test parent IDs: 50
# train parent IDs: 342
# missing_in_train: 0
# extra_in_train: 292
# missing_in_train examples: []
# extra_in_train examples: ['T1001', 'T1002', 'T1004', 'T1006', 'T1007', 'T1008', 'T1009', 'T1010', 'T1011', 'T1013', 'T1014', 'T1015', 'T1017', 'T1019', 'T1020', 'T1022', 'T1023', 'T1024', 'T1025', 'T1026', 'T1028', 'T1029', 'T1030', 'T1031', 'T1032', 'T1034', 'T1035', 'T1037', 'T1038', 'T1039']

# %%
# train_filtered を使ってもう一回差分確認
trainF = train_filtered.copy()
trainF["_base"] = trainF["Key"].map(base_tid)

trainF_base_set = set(trainF["_base"].dropna().unique())

missing_in_trainF = sorted(test_base_set - trainF_base_set)
extra_in_trainF   = sorted(trainF_base_set - test_base_set)

print("train_filtered parent IDs:", len(trainF_base_set))
print("missing_in_trainF:", len(missing_in_trainF))
print("extra_in_trainF:", len(extra_in_trainF))
print("missing_in_trainF examples:", missing_in_trainF[:30])
print("extra_in_trainF examples:", extra_in_trainF[:30])
# Out:
# train_filtered parent IDs: 50
# missing_in_trainF: 0
# extra_in_trainF: 0
# missing_in_trainF examples: []
# extra_in_trainF examples: []

# %%
train = train_main

# %%
from sentence_transformers import SentenceTransformer
from langchain_community.embeddings import HuggingFaceEmbeddings
import torch

device = "cuda:1"
model = SentenceTransformer(
    "sentence-transformers/multi-qa-MiniLM-L6-cos-v1", #GPU1を使用
    device=device
)
# embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/multi-qa-MiniLM-L6-cos-v1")
# model = SentenceTransformer("sentence-transformers/multi-qa-MiniLM-L6-cos-v1")

docs = []
texts = []
embeddings_list = []

for index, row in train.iterrows(): #dictionaly_Mitsu
    text = row["Value"]
    emb = model.encode(text, convert_to_numpy=True)

    doc = Document(
        page_content=text,
        metadata={
            "TTP_ID": row["Key"]        # ATT&CK IDの正解ラベル（T1059とか）
        },
    )

    docs.append(doc)
    texts.append(text)
    embeddings_list.append(emb)

# %%
docs[0]
# Out:
# Document(metadata={'TTP_ID': 'T1094'}, page_content='Some Software variants use raw TCP for C2.')

# %%
import faiss
import numpy as np

# ① ベクトル次元
d = embeddings_list[0].shape[0]  # 384 次元とか

# ② FAISS index を作成（L2距離）
index = faiss.IndexFlatL2(d)

# ③ numpy 配列にまとめる
emb_matrix = np.vstack(embeddings_list).astype('float32')

# ④ インデックスへ追加
index.add(emb_matrix)

print("FAISS に追加された件数:", index.ntotal)
# Out:
# FAISS に追加された件数: 8847

# %%
# 類似検索テスト
query = model.encode(test.iloc[0]["Sentences"], convert_to_numpy=True).astype('float32')

k = 45
distances, indices = index.search(query.reshape(1, -1), k)

print(indices)
print(distances)
# Out:
# [[3476 7344 8336 8522 3740 3330 3608 8263 7424 6051 8149 1204  787 6684
#   1890 8404 8176 7827 7625  294 2623 4198 1668 7548 8406 6351 7194 1257
#   7559 8083 5671 3021 2618  207 1062 6374 6931  372 6750 4887 4225 8606
#   4297 4574  666]]
# [[0.8448929  0.91808504 0.9404224  0.954873   0.9601603  0.9618082
#   0.9806144  1.0138112  1.0184844  1.0193832  1.0212893  1.0234567
#   1.0257134  1.0282106  1.0334785  1.0398726  1.0413783  1.0471346
#   1.0475119  1.0500329  1.052748   1.0556294  1.059175   1.0613909
#   1.0615077  1.0630999  1.0634594  1.065839   1.0662494  1.0664468
#   1.0667781  1.0716722  1.0758204  1.0766556  1.0810692  1.0826294
#   1.0846196  1.0865464  1.0866022  1.0915204  1.0937612  1.0963136
#   1.0974312  1.1004199  1.1015258 ]]

# %%
import re, pandas as pd

def base_tid(x):
    if pd.isna(x): return None
    m = re.search(r"(T\d{4})", str(x))
    return m.group(1) if m else None

K = 1
strict_hit = 0
parent_hit = 0

for _, row in test.iterrows():
    q = model.encode(row["Sentences"], convert_to_numpy=True).astype("float32")
    _, I = index.search(q.reshape(1, -1), K)

    pred = docs[I[0][0]].metadata["TTP_ID"]
    gold = row["act_Technique ID"]

    if str(gold) == str(pred):
        strict_hit += 1
    if base_tid(gold) == base_tid(pred):
        parent_hit += 1

print("Recall@1 strict :", strict_hit/len(test))
print("Recall@1 parent :", parent_hit/len(test))
# Out:
# Recall@1 strict : 0.5184743742550656
# Recall@1 parent : 0.5184743742550656

# %%
test["act_Technique ID"].astype(str).str.contains(r"\.", regex=True).mean()
# Out:
# np.float64(0.0)

# %%
import re
import pandas as pd

def base_tid(x):
    if pd.isna(x):
        return None
    m = re.search(r"(T\d{4})", str(x))
    return m.group(1) if m else None

Ks = [1,45]
results = {}

for K in Ks:
    recall_hit = 0

    for _, row in test.iterrows():
        query_vec = model.encode(row["Sentences"], convert_to_numpy=True).astype("float32")
        distances, indices = index.search(query_vec.reshape(1, -1), K)

        retrieved_ttps = [docs[i].metadata["TTP_ID"] for i in indices[0]]

        gold_base = base_tid(row["act_Technique ID"])
        retrieved_base_set = {base_tid(t) for t in retrieved_ttps}

        if gold_base in retrieved_base_set:
            recall_hit += 1

    recall_k = recall_hit / len(test)
    results[K] = recall_k
    print(f"Recall@{K:3d} (parent-match) = {recall_k:.4f}")
# Out:
# Recall@  1 (parent-match) = 0.5185
# Recall@ 45 (parent-match) = 0.8570

# %%
df
# Out:
#         ID test_or_train act_Technique ID  \
# 0        1         train            T1543
# 1        2         train            T1562
# 2        3         train            T1036
# 3        4         train            T1036
# 4        5         train            T1588
# ...    ...           ...              ...
# 8382  8383         train            T1573
# 8383  8384         train            T1041
# 8384  8385         train            T1083
# 8385  8386          test            T1057
# 8386  8387          test            T1087
#
#                                      act_Technique Name  \
# 0      Create or Modify System Process: Windows Service
# 1     Impair Defenses: Disable or Modify System Fire...
# 2              Masquerading: Masquerade Task or Service
# 3       Masquerading: Match Legitimate Name or Location
# 4                             Obtain Capabilities: Tool
# ...                                                 ...
# 8382          Encrypted Channel: Symmetric Cryptography
# 8383                       Exfiltration Over C2 Channel
# 8384                       File and Directory Discovery
# 8385                                  Process Discovery
# 8386                   Account Discovery: Email Account
#
#                        act_TacticsName  \
# 0     Persistence:Privilege Escalation
# 1                      Defense Evasion
# 2                      Defense Evasion
# 3                      Defense Evasion
# 4                 Resource Development
# ...                                ...
# 8382               Command and Control
# 8383                      Exfiltration
# 8384                         Discovery
# 8385                         Discovery
# 8386                         Discovery
#
#                                               Sentences Predicted_TacticsName
# 0     Carbanak malware installs itself as a service ...                   NaN
# 1     Carbanak may use netsh to add local firewall r...                   NaN
# 2     Carbanak has copied legitimate service names t...                   NaN
# 3     Carbanak has named malware "svchost.exe," whic...                   NaN
# 4     Carbanak has obtained and used open-source too...                   NaN
# ...                                                 ...                   ...
# 8382  NETEAGLE will decrypt resources it downloads w...                   NaN
# 8383  NETEAGLE is capable of reading files over the ...                   NaN
# 8384  NETEAGLE allows adversaries to enumerate and m...                   NaN
# 8385  NETEAGLE can send process listings over the C2...          Exfiltration
# 8386  Ruler can be used to enumerate Exchange users ...             Discovery
#
# [8387 rows x 7 columns]

# %%
df2
# Out:
#              Key                                              Value
# 0          T1094         Some Software variants use raw TCP for C2.
# 1          T1047  Software leverages WMI to enumerate anti-virus...
# 2      T1003.001  Software contains an implementation of Softwar...
# 3      T1614.001  Attacker has used implants to collect the syst...
# 4      T1587.001                     For Software modular backdoor.
# ...          ...                                                ...
# 19742      T1045  Most decompression techniques decompress the e...
# 19743  T1059.001  Software uses PowerShell to download and execu...
# 19744  T1059.003  Software can use `cmd.exe` to execute a create...
# 19745      T1112  Software has functionality to remove Registry ...
# 19746  T1204.001  Links may also lead users to download files th...
#
# [19747 rows x 2 columns]

# %% [markdown]
# # 生成テスト用（TacticsのBERT)

# %%
from collections import Counter
import numpy as np
import re
import pandas as pd

K = 45

number = 3
a = number - 1
row = test.iloc[a]

query_text = row["Sentences"]
true_tid   = row["act_Technique ID"]
true_tac   = row.get("act_TacticsName")

def norm_tid(x):
    if pd.isna(x):
        return None
    m = re.search(r"(T\d{4})", str(x))
    return m.group(1) if m else str(x)

true_tid_n = norm_tid(true_tid)

query_vec = model.encode(query_text, convert_to_numpy=True).astype("float32")
distances, indices = index.search(query_vec.reshape(1, -1), K)

top_k_indices = indices[0]
top_k_dists   = distances[0]

retrieved_tids   = [docs[i].metadata.get("TTP_ID") for i in top_k_indices]
retrieved_tids_n = [norm_tid(t) for t in retrieved_tids]

print(f"===== {number}件目のチェック =====")
print(f"Technique ID (真値) : {true_tid}  -> 正規化: {true_tid_n}")
if true_tac is not None:
    print(f"Tactics (真値)      : {true_tac}")
print()
print(f"入力CTI文:\n{query_text}\n")

# 親IDで最初に出てきたものだけ残す（順位は維持）
seen = set()
unique_by_parent = []
for rank, (idx_i, dist) in enumerate(zip(top_k_indices, top_k_dists), start=1):
    meta = docs[idx_i].metadata
    tid = meta.get("TTP_ID")
    p = norm_tid(tid)
    if p in seen:
        continue
    seen.add(p)
    unique_by_parent.append((rank, idx_i, dist, tid))

print(f"上位 {K} 件から抽出 → 親IDで重複除去後 {len(unique_by_parent)} 件:")
for new_rank, (orig_rank, idx_i, dist, tid) in enumerate(unique_by_parent, start=1):
    meta = docs[idx_i].metadata
    print(f"{new_rank:2d}. (orig#{orig_rank:2d}) ID={tid}  "
          f"Name={meta.get('TechniqueName','')}  "
          f"Tactics={meta.get('Tactics','')}  "
          f"dist={dist:.4f}")

print()
print(f"親ID一致（サブOK） -> {true_tid_n in set(retrieved_tids_n)}")
print(f"完全一致（参考）   -> {str(true_tid) in set(map(str, retrieved_tids))}")
# Out:
# ===== 3件目のチェック =====
# Technique ID (真値) : T1566  -> 正規化: T1566
# Tactics (真値)      : Initial Access
#
# 入力CTI文:
# Frankenstein has used spearphishing emails to send trojanized Microsoft Word documents.[1]
#
# 上位 45 件から抽出 → 親IDで重複除去後 19 件:
#  1. (orig# 1) ID=T1593  Name=  Tactics=  dist=0.7024
#  2. (orig# 2) ID=T1221  Name=  Tactics=  dist=0.7498
#  3. (orig# 3) ID=T1192  Name=  Tactics=  dist=0.8042
#  4. (orig# 4) ID=T1204  Name=  Tactics=  dist=0.8182
#  5. (orig# 5) ID=T1105  Name=  Tactics=  dist=0.8185
#  6. (orig# 6) ID=T1587  Name=  Tactics=  dist=0.8255
#  7. (orig# 7) ID=T1193  Name=  Tactics=  dist=0.8817
#  8. (orig# 8) ID=T1566  Name=  Tactics=  dist=0.8835
#  9. (orig#11) ID=T1203  Name=  Tactics=  dist=0.9052
# 10. (orig#12) ID=T1534  Name=  Tactics=  dist=0.9127
# 11. (orig#14) ID=T1083  Name=  Tactics=  dist=0.9226
# 12. (orig#15) ID=T1583  Name=  Tactics=  dist=0.9276
# 13. (orig#16) ID=T1114  Name=  Tactics=  dist=0.9406
# 14. (orig#18) ID=T1078  Name=  Tactics=  dist=0.9421
# 15. (orig#21) ID=T1039  Name=  Tactics=  dist=0.9650
# 16. (orig#33) ID=T1005  Name=  Tactics=  dist=0.9978
# 17. (orig#38) ID=T1586  Name=  Tactics=  dist=1.0103
# 18. (orig#39) ID=T1173  Name=  Tactics=  dist=1.0153
# 19. (orig#42) ID=T1528  Name=  Tactics=  dist=1.0251
#
# 親ID一致（サブOK） -> True
# 完全一致（参考）   -> True

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/multi-qa-MiniLM-L6-cos-v1",
    model_kwargs={"device": "cuda:1"} #GPU指定
)

# %%
from langchain_community.vectorstores import FAISS as LCFAISS
db = LCFAISS.from_documents(docs, embeddings)
db.save_local("TTPHunter_50_TTPs_andTactics_2")

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS as LCFAISS

# 1. 保存時と同じモデル名で embeddings（モデル）を復元
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/multi-qa-MiniLM-L6-cos-v1",
    model_kwargs={"device": "cuda:1"} #GPU指定
    # SecureBERT 使って保存したなら、ここも同じ名前にする
)

# 2. ローカルからベクターストアをロード
db = LCFAISS.load_local(
    "TTPHunter_50_TTPs_andTactics_2",
    embeddings,
    allow_dangerous_deserialization=True
)

print("loaded FAISS index:", db)

docs = db.similarity_search("test", k=1)
doc = docs[0]
print(doc.metadata)  # ここに "Tactics" が見えてたらOK
# Out:
# loaded FAISS index: <langchain_community.vectorstores.faiss.FAISS object at 0x7efddc307910>
# {'TTP_ID': 'T1086'}

# %%
test
# Out:
#         ID test_or_train act_Technique ID  \
# 14      15          test            T1005
# 20      21          test            T1588
# 22      23          test            T1566
# 23      24          test            T1057
# 29      30          test            T1204
# ...    ...           ...              ...
# 8368  8369          test            T1562
# 8369  8370          test            T1070
# 8381  8382          test            T1059
# 8385  8386          test            T1057
# 8386  8387          test            T1087
#
#                                      act_Technique Name       act_TacticsName  \
# 14                               Data from Local System            Collection
# 20                            Obtain Capabilities: Tool  Resource Development
# 22                   Phishing: Spearphishing Attachment        Initial Access
# 23                                    Process Discovery             Discovery
# 29                       User Execution: Malicious File             Execution
# ...                                                 ...                   ...
# 8368  Impair Defenses: Disable or Modify System Fire...       Defense Evasion
# 8369           Indicator Removal on Host: File Deletion       Defense Evasion
# 8381  Command and Scripting Interpreter: Windows Com...             Execution
# 8385                                  Process Discovery             Discovery
# 8386                   Account Discovery: Email Account             Discovery
#
#                                               Sentences Predicted_TacticsName
# 14    Frankenstein has enumerated hosts via Empire, ...             Discovery
# 20    Frankenstein has obtained and used Empire to d...             Execution
# 22    Frankenstein has used spearphishing emails to ...        Initial Access
# 23    Frankenstein has enumerated hosts, looking to ...             Discovery
# 29    Frankenstein has used trojanized Microsoft Wor...             Execution
# ...                                                 ...                   ...
# 8368  TYPEFRAME can open the Windows Firewall on the...       Defense Evasion
# 8369      TYPEFRAME can delete files off the system.[1]       Defense Evasion
# 8381  NETEAGLE allows adversaries to execute shell c...             Execution
# 8385  NETEAGLE can send process listings over the C2...          Exfiltration
# 8386  Ruler can be used to enumerate Exchange users ...             Discovery
#
# [1678 rows x 7 columns]

# %% [markdown]
# ### Few-Shot Learning

# %%
import sys
print(sys.executable)
# Out:
# /workspace/miluser/Mitsuharu_2002/mitsuharu-12-02/bin/python

# %%
# !pwd
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /workspace/miluser/Mitsuharu_2002

# %% [markdown]
# # llama 読み込み

# %%
# !pip install llama-cpp-python

from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/Llama-3.3-70B-Instruct-GGUF",
	filename="Llama-3.3-70B-Instruct-Q5_K_M.gguf",
	cache_dir = "/workspace/miluser/Mitsuharu_2002/llama_cache",
    n_ctx=4000,
    n_gpu_layers=-1,          # できるだけ GPU に載せる
    main_gpu=0,               # 小さいテンソルは GPU0 で処理
    tensor_split=[0.5, 0.5],  # 大きいテンソルを GPU0/1 に 50:50 で分割
    verbose=False,             # ロードログを出す
)

llm.create_chat_completion(
	messages = [
		{
			"role": "user",
			"content": "What is the capital of France?"
		}
	]
)
# Out:
# llama_context: n_ctx_per_seq (4000) < n_ctx_train (131072) -- the full capacity of the model will not be utilized
# {'id': 'chatcmpl-3cc4a879-9dc1-451f-a9ca-f3e85670fb6b',
#  'object': 'chat.completion',
#  'created': 1766547364,
#  'model': '/workspace/miluser/Mitsuharu_2002/llama_cache/models--unsloth--Llama-3.3-70B-Instruct-GGUF/snapshots/8f14c5c5d06fca109ff16f94496147a8479711de/./Llama-3.3-70B-Instruct-Q5_K_M.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': 'The capital of France is Paris.'},
#    'logprobs': None,
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 42, 'completion_tokens': 7, 'total_tokens': 49}}

# %%
df
# Out:
#         ID test_or_train act_Technique ID  \
# 0        1         train            T1543
# 1        2         train            T1562
# 2        3         train            T1036
# 3        4         train            T1036
# 4        5         train            T1588
# ...    ...           ...              ...
# 8382  8383         train            T1573
# 8383  8384         train            T1041
# 8384  8385         train            T1083
# 8385  8386          test            T1057
# 8386  8387          test            T1087
#
#                                      act_Technique Name  \
# 0      Create or Modify System Process: Windows Service
# 1     Impair Defenses: Disable or Modify System Fire...
# 2              Masquerading: Masquerade Task or Service
# 3       Masquerading: Match Legitimate Name or Location
# 4                             Obtain Capabilities: Tool
# ...                                                 ...
# 8382          Encrypted Channel: Symmetric Cryptography
# 8383                       Exfiltration Over C2 Channel
# 8384                       File and Directory Discovery
# 8385                                  Process Discovery
# 8386                   Account Discovery: Email Account
#
#                        act_TacticsName  \
# 0     Persistence:Privilege Escalation
# 1                      Defense Evasion
# 2                      Defense Evasion
# 3                      Defense Evasion
# 4                 Resource Development
# ...                                ...
# 8382               Command and Control
# 8383                      Exfiltration
# 8384                         Discovery
# 8385                         Discovery
# 8386                         Discovery
#
#                                               Sentences Predicted_TacticsName
# 0     Carbanak malware installs itself as a service ...                   NaN
# 1     Carbanak may use netsh to add local firewall r...                   NaN
# 2     Carbanak has copied legitimate service names t...                   NaN
# 3     Carbanak has named malware "svchost.exe," whic...                   NaN
# 4     Carbanak has obtained and used open-source too...                   NaN
# ...                                                 ...                   ...
# 8382  NETEAGLE will decrypt resources it downloads w...                   NaN
# 8383  NETEAGLE is capable of reading files over the ...                   NaN
# 8384  NETEAGLE allows adversaries to enumerate and m...                   NaN
# 8385  NETEAGLE can send process listings over the C2...          Exfiltration
# 8386  Ruler can be used to enumerate Exchange users ...             Discovery
#
# [8387 rows x 7 columns]

# %%
import re
from llama_cpp import Llama   # もう import 済みなら不要


# # ★ llm はループの外で1回だけ作る
# llm = Llama.from_pretrained(
#     repo_id="unsloth/Llama-3.3-70B-Instruct-GGUF",
#     filename="Llama-3.3-70B-Instruct-Q8_0/Llama-3.3-70B-Instruct-Q8_0-00001-of-00002.gguf",
#     # オプション（必要に応じて）
#     n_ctx=4000,
#     n_gpu_layers=-1,  # GPU 使うなら。全部GPUに乗せるなら -1
#     # main_gpu=1,     # GPU1番を使いたいならこういう指定もアリ（バージョンによる）
#     verbose=False, 
# )

predicted_labels = []

for index, row in test.iterrows():
    text_to_predict = row["Sentences"]
    id = row["ID"]

    # 1. MiniLM + FAISS で 65件取得（few-shot数）
    search_results = db.similarity_search_with_score(text_to_predict, k=55)

    # 2. score < 2 のものだけ例として採用
    xs = [
        "\nText:" + doc.page_content.lower().strip() +
        "\nSimilarity:" + str(score) + "\n" +
        "Classification:" + doc.metadata['TTP_ID'] + "\n"
        for doc, score in search_results
        if score < 2
    ]

    examples_block = ''.join(xs)

    prompt = (
        "You are a cybersecurity expert.\n"
        "Your task is to classify the last sentence of 'InputText' based on the provided examples.\n"
        "Each example shows a sentence, a similarity score (smaller value means more similar), "
        "and its corresponding classification label.\n"
        "Rules:\n"
        "- You MUST answer with exactly ONE classification label.\n"
        "- The label MUST start with 'T' followed by 4 digits (e.g., T1082).\n"
        "- Do NOT output '?', explanations, or anything else.\n"
        "- If you are unsure, choose the most plausible label from the patterns in the examples.\n\n"
        "Examples:\n"
        f"{examples_block}\n"
        f"InputText:{text_to_predict.lower().strip()}\n"
        "Classification:"
    )

    # ★ llama.cpp / unsloth のチャットAPIだけに統一する
    out = llm.create_chat_completion(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        temperature=0.0,
        max_tokens=16,  # ラベルだけ返ってくればいいので小さめでOK
    )

    # ★ chat形式なので "message"]["content"] に入ってる
    raw = out["choices"][0]["message"]["content"]

    # 3. 出力から Txxxx を正規表現で抜き出す
    m = re.search(r"T\d{4}", raw)
    if m:
        predicted_label = m.group(0)
    else:
        # 方針次第でここをどうするか決める
        predicted_label = ""
        # 例えば最近傍にフォールバックするならこう（使うならコメント外す）
        # best_doc, best_score = min(search_results, key=lambda x: x[1])
        # predicted_label = best_doc.metadata['TTP_ID']

    predicted_labels.append(predicted_label)
    print("ID:", id, ", actual:", row["act_Technique ID"], ", predicted:", predicted_label)
# Out:
# ID: 15 , actual: T1005 , predicted: T1082
# ID: 21 , actual: T1588 , predicted: T1105
# ID: 23 , actual: T1566 , predicted: T1221
# ID: 24 , actual: T1057 , predicted: T1057
# ID: 30 , actual: T1204 , predicted: T1221
# ID: 32 , actual: T1047 , predicted: T1047
# ID: 33 , actual: T1087 , predicted: T1069
# ID: 34 , actual: T1087 , predicted: T1069
# ID: 39 , actual: T1547 , predicted: T1112
# ID: 40 , actual: T1059 , predicted: T1059
# ID: 43 , actual: T1005 , predicted: T1005
# ID: 45 , actual: T1041 , predicted: T1041
# ID: 49 , actual: T1036 , predicted: T1036
# ID: 50 , actual: T1036 , predicted: T1036
# ID: 51 , actual: T1027 , predicted: T1027
# ID: 52 , actual: T1588 , predicted: T1003
# ID: 66 , actual: T1078 , predicted: T1078
# ID: 71 , actual: T1105 , predicted: T1105
# ID: 73 , actual: T1553 , predicted: T1116
# ID: 86 , actual: T1553 , predicted: T1553
# ID: 91 , actual: T1087 , predicted: T1087
# ID: 99 , actual: T1555 , predicted: T1003
# ID: 120 , actual: T1021 , predicted: T1133
# ID: 125 , actual: T1016 , predicted: T1016
# ID: 126 , actual: T1049 , predicted: T1049
# ID: 134 , actual: T1059 , predicted: T1064
# ID: 135 , actual: T1059 , predicted: T1059
# ID: 138 , actual: T1070 , predicted: T1070
# ID: 139 , actual: T1105 , predicted: T1105
# ID: 141 , actual: T1112 , predicted: T1112
# ID: 144 , actual: T1588 , predicted: T1003
# ID: 145 , actual: T1003 , predicted: T1003
# ID: 148 , actual: T1090 , predicted: T1090
# ID: 149 , actual: T1021 , predicted: T1076
# ID: 153 , actual: T1553 , predicted: T1198
# ID: 155 , actual: T1569 , predicted: T1106
# ID: 157 , actual: T1078 , predicted: T1078
# ID: 159 , actual: T1059 , predicted: T1047
# ID: 160 , actual: T1059 , predicted: T1057
# ID: 163 , actual: T1573 , predicted: T1032
# ID: 168 , actual: T1027 , predicted: T1104
# ID: 171 , actual: T1218 , predicted: T1105
# ID: 177 , actual: T1102 , predicted: T1105
# ID: 186 , actual: T1204 , predicted: T1192
# ID: 188 , actual: T1071 , predicted: T1041
# ID: 189 , actual: T1071 , predicted: T1105
# ID: 192 , actual: T1560 , predicted: T1022
# ID: 195 , actual: T1059 , predicted: T1059
# ID: 197 , actual: T1059 , predicted: T1114
# ID: 201 , actual: T1005 , predicted: T1005
# ID: 203 , actual: T1140 , predicted: T1140
# ID: 211 , actual: T1070 , predicted: T1099
# ID: 215 , actual: T1036 , predicted: T1050
# ID: 218 , actual: T1027 , predicted: T1027
# ID: 222 , actual: T1003 , predicted: T1003
# ID: 225 , actual: T1057 , predicted: T1057
# ID: 227 , actual: T1055 , predicted: T1093
# ID: 228 , actual: T1012 , predicted: T1012
# ID: 230 , actual: T1053 , predicted: T1105
# ID: 234 , actual: T1218 , predicted: T1117
# ID: 235 , actual: T1218 , predicted: T1085
# ID: 245 , actual: T1059 , predicted: T1059
# ID: 248 , actual: T1555 , predicted: T1556
# ID: 258 , actual: T1012 , predicted: T1012
# ID: 273 , actual: T1105 , predicted: T1105
# ID: 274 , actual: T1056 , predicted: T1056
# ID: 275 , actual: T1036 , predicted: T1554
# ID: 277 , actual: T1566 , predicted: T1193
# ID: 278 , actual: T1057 , predicted: T1057
# ID: 284 , actual: T1204 , predicted: T1193
# ID: 288 , actual: T1059 , predicted: T1064
# ID: 291 , actual: T1027 , predicted: T1027
# ID: 292 , actual: T1588 , predicted: T1554
# ID: 295 , actual: T1204 , predicted: T1064
# ID: 296 , actual: T1560 , predicted: T1560
# ID: 297 , actual: T1560 , predicted: T1027
# ID: 305 , actual: T1059 , predicted: T1059
# ID: 309 , actual: T1083 , predicted: T1083
# ID: 312 , actual: T1070 , predicted: T1107
# ID: 314 , actual: T1070 , predicted: T1099
# ID: 318 , actual: T1106 , predicted: T1106
# ID: 319 , actual: T1027 , predicted: T1045
# ID: 322 , actual: T1057 , predicted: T1057
# ID: 327 , actual: T1218 , predicted: T1085
# ID: 348 , actual: T1055 , predicted: T1055
# ID: 357 , actual: T1566 , predicted: T1566
# ID: 370 , actual: T1566 , predicted: T1193
# ID: 379 , actual: T1059 , predicted: T1059
# ID: 380 , actual: T1059 , predicted: T1059
# ID: 381 , actual: T1059 , predicted: T1064
# ID: 389 , actual: T1566 , predicted: T1193
# ID: 394 , actual: T1518 , predicted: T1047
# ID: 395 , actual: T1218 , predicted: T1191
# ID: 397 , actual: T1218 , predicted: T1117
# ID: 410 , actual: T1074 , predicted: T1041
# ID: 419 , actual: T1112 , predicted: T1112
# ID: 421 , actual: T1027 , predicted: T1045
# ID: 423 , actual: T1003 , predicted: T1003
# ID: 445 , actual: T1059 , predicted: T1064
# ID: 452 , actual: T1574 , predicted: T1073
# ID: 455 , actual: T1105 , predicted: T1105
# ID: 457 , actual: T1036 , predicted: T1192
# ID: 463 , actual: T1566 , predicted: T1193
# ID: 465 , actual: T1053 , predicted: T1053
# ID: 468 , actual: T1518 , predicted: T1518
# ID: 471 , actual: T1102 , predicted: T1105
# ID: 476 , actual: T1560 , predicted: T1560
# ID: 480 , actual: T1059 , predicted: T1086
# ID: 488 , actual: T1083 , predicted: T1083
# ID: 490 , actual: T1105 , predicted: T1105
# ID: 496 , actual: T1588 , predicted: T1003
# ID: 500 , actual: T1566 , predicted: T1566
# ID: 503 , actual: T1012 , predicted: T1012
# ID: 510 , actual: T1553 , predicted: T1112
# ID: 520 , actual: T1566 , predicted: T1221
# ID: 522 , actual: T1071 , predicted: T1571
# ID: 527 , actual: T1005 , predicted: T1005
# ID: 528 , actual: T1140 , predicted: T1140
# ID: 529 , actual: T1041 , predicted: T1041
# ID: 531 , actual: T1564 , predicted: T1143
# ID: 533 , actual: T1070 , predicted: T1107
# ID: 534 , actual: T1105 , predicted: T1105
# ID: 537 , actual: T1106 , predicted: T1106
# ID: 542 , actual: T1057 , predicted: T1057
# ID: 544 , actual: T1053 , predicted: T1053
# ID: 549 , actual: T1016 , predicted: T1018
# ID: 558 , actual: T1027 , predicted: T1573
# ID: 559 , actual: T1588 , predicted: T1003
# ID: 560 , actual: T1003 , predicted: T1003
# ID: 573 , actual: T1106 , predicted: T1106
# ID: 575 , actual: T1027 , predicted: T1009
# ID: 579 , actual: T1053 , predicted: T1053
# ID: 594 , actual: T1049 , predicted: T1049
# ID: 598 , actual: T1053 , predicted: T1105
# ID: 614 , actual: T1021 , predicted: T1076
# ID: 630 , actual: T1566 , predicted: T1193
# ID: 635 , actual: T1560 , predicted: T1560
# ID: 636 , actual: T1059 , predicted: T1105
# ID: 642 , actual: T1547 , predicted: T1060
# ID: 643 , actual: T1059 , predicted: T1059
# ID: 652 , actual: T1070 , predicted: T1070
# ID: 661 , actual: T1049 , predicted: T1049
# ID: 668 , actual: T1036 , predicted: T1036
# ID: 676 , actual: T1087 , predicted: T1033
# ID: 684 , actual: T1059 , predicted: T1086
# ID: 685 , actual: T1555 , predicted: T1555
# ID: 688 , actual: T1140 , predicted: T1140
# ID: 693 , actual: T1036 , predicted: T1112
# ID: 694 , actual: T1027 , predicted: T1027
# ID: 701 , actual: T1566 , predicted: T1193
# ID: 705 , actual: T1053 , predicted: T1053
# ID: 714 , actual: T1049 , predicted: T1049
# ID: 720 , actual: T1087 , predicted: T1033
# ID: 723 , actual: T1071 , predicted: T1041
# ID: 726 , actual: T1547 , predicted: T1060
# ID: 734 , actual: T1140 , predicted: T1140
# ID: 738 , actual: T1112 , predicted: T1112
# ID: 748 , actual: T1055 , predicted: T1055
# ID: 761 , actual: T1124 , predicted: T1124
# ID: 769 , actual: T1087 , predicted: T1033
# ID: 772 , actual: T1059 , predicted: T1064
# ID: 774 , actual: T1543 , predicted: T1050
# ID: 777 , actual: T1074 , predicted: T1074
# ID: 780 , actual: T1564 , predicted: T1143
# ID: 788 , actual: T1003 , predicted: T1003
# ID: 795 , actual: T1018 , predicted: T1018
# ID: 801 , actual: T1033 , predicted: T1033
# ID: 803 , actual: T1078 , predicted: T1078
# ID: 822 , actual: T1106 , predicted: T1106
# ID: 832 , actual: T1090 , predicted: T1100
# ID: 835 , actual: T1018 , predicted: T1018
# ID: 840 , actual: T1016 , predicted: T1016
# ID: 841 , actual: T1049 , predicted: T1049
# ID: 843 , actual: T1569 , predicted: T1050
# ID: 844 , actual: T1124 , predicted: T1124
# ID: 845 , actual: T1078 , predicted: T1078
# ID: 853 , actual: T1059 , predicted: T1059
# ID: 864 , actual: T1105 , predicted: T1105
# ID: 865 , actual: T1056 , predicted: T1003
# ID: 866 , actual: T1112 , predicted: T1112
# ID: 875 , actual: T1090 , predicted: T1090
# ID: 876 , actual: T1090 , predicted: T1090
# ID: 879 , actual: T1021 , predicted: T1135
# ID: 881 , actual: T1053 , predicted: T1053
# ID: 883 , actual: T1518 , predicted: T1518
# ID: 889 , actual: T1124 , predicted: T1124
# ID: 892 , actual: T1078 , predicted: T1078
# ID: 896 , actual: T1059 , predicted: T1064
# ID: 901 , actual: T1574 , predicted: T1073
# ID: 909 , actual: T1518 , predicted: T1047
# ID: 913 , actual: T1033 , predicted: T1033
# ID: 915 , actual: T1204 , predicted: T1189
# ID: 917 , actual: T1071 , predicted: T1008
# ID: 918 , actual: T1547 , predicted: T1112
# ID: 931 , actual: T1055 , predicted: T1055
# ID: 939 , actual: T1560 , predicted: T1005
# ID: 945 , actual: T1082 , predicted: T1082
# ID: 950 , actual: T1547 , predicted: T1187
# ID: 959 , actual: T1562 , predicted: T1089
# ID: 964 , actual: T1112 , predicted: T1112
# ID: 972 , actual: T1021 , predicted: T1210
# ID: 977 , actual: T1033 , predicted: T1033
# ID: 979 , actual: T1078 , predicted: T1078
# ID: 980 , actual: T1087 , predicted: T1003
# ID: 981 , actual: T1560 , predicted: T1560
# ID: 983 , actual: T1547 , predicted: T1112
# ID: 984 , actual: T1059 , predicted: T1059
# ID: 985 , actual: T1059 , predicted: T1105
# ID: 988 , actual: T1555 , predicted: T1555
# ID: 990 , actual: T1005 , predicted: T1005
# ID: 995 , actual: T1036 , predicted: T1036
# ID: 1004 , actual: T1053 , predicted: T1053
# ID: 1015 , actual: T1105 , predicted: T1105
# ID: 1023 , actual: T1021 , predicted: T1076
# ID: 1030 , actual: T1566 , predicted: T1193
# ID: 1035 , actual: T1059 , predicted: T1064
# ID: 1036 , actual: T1059 , predicted: T1064
# ID: 1045 , actual: T1087 , predicted: T1087
# ID: 1052 , actual: T1074 , predicted: T1074
# ID: 1061 , actual: T1106 , predicted: T1106
# ID: 1064 , actual: T1003 , predicted: T1003
# ID: 1067 , actual: T1012 , predicted: T1012
# ID: 1071 , actual: T1018 , predicted: T1018
# ID: 1083 , actual: T1547 , predicted: T1112
# ID: 1086 , actual: T1059 , predicted: T1064
# ID: 1088 , actual: T1555 , predicted: T1003
# ID: 1090 , actual: T1105 , predicted: T1105
# ID: 1092 , actual: T1106 , predicted: T1055
# ID: 1104 , actual: T1204 , predicted: T1193
# ID: 1113 , actual: T1074 , predicted: T1074
# ID: 1122 , actual: T1036 , predicted: T1036
# ID: 1123 , actual: T1036 , predicted: T1112
# ID: 1128 , actual: T1003 , predicted: T1003
# ID: 1133 , actual: T1090 , predicted: T1090
# ID: 1140 , actual: T1016 , predicted: T1016
# ID: 1141 , actual: T1049 , predicted: T1049
# ID: 1143 , actual: T1078 , predicted: T1078
# ID: 1144 , actual: T1047 , predicted: T1047
# ID: 1151 , actual: T1070 , predicted: T1070
# ID: 1157 , actual: T1566 , predicted: T1193
# ID: 1162 , actual: T1018 , predicted: T1018
# ID: 1168 , actual: T1102 , predicted: T1102
# ID: 1169 , actual: T1047 , predicted: T1047
# ID: 1173 , actual: T1560 , predicted: T1002
# ID: 1181 , actual: T1573 , predicted: T1094
# ID: 1186 , actual: T1070 , predicted: T1070
# ID: 1217 , actual: T1588 , predicted: T1018
# ID: 1221 , actual: T1059 , predicted: T1064
# ID: 1235 , actual: T1021 , predicted: T1219
# ID: 1236 , actual: T1204 , predicted: T1192
# ID: 1238 , actual: T1071 , predicted: T1043
# ID: 1241 , actual: T1105 , predicted: T1105
# ID: 1247 , actual: T1027 , predicted: T1027
# ID: 1256 , actual: T1036 , predicted: T1036
# ID: 1260 , actual: T1218 , predicted: T1059
# ID: 1262 , actual: T1204 , predicted: T1193
# ID: 1271 , actual: T1016 , predicted: T1016
# ID: 1278 , actual: T1005 , predicted: T1005
# ID: 1279 , actual: T1074 , predicted: T1030
# ID: 1283 , actual: T1036 , predicted: T1036
# ID: 1284 , actual: T1027 , predicted: T1027
# ID: 1285 , actual: T1027 , predicted: T1045
# ID: 1291 , actual: T1018 , predicted: T1018
# ID: 1315 , actual: T1071 , predicted: T1043
# ID: 1316 , actual: T1071 , predicted: T1008
# ID: 1327 , actual: T1574 , predicted: T1073
# ID: 1333 , actual: T1027 , predicted: T1036
# ID: 1335 , actual: T1057 , predicted: T1057
# ID: 1344 , actual: T1078 , predicted: T1078
# ID: 1353 , actual: T1090 , predicted: T1188
# ID: 1358 , actual: T1204 , predicted: T1566
# ID: 1364 , actual: T1555 , predicted: T1555
# ID: 1365 , actual: T1555 , predicted: T1555
# ID: 1374 , actual: T1071 , predicted: T1187
# ID: 1377 , actual: T1059 , predicted: T1064
# ID: 1380 , actual: T1573 , predicted: T1032
# ID: 1381 , actual: T1083 , predicted: T1083
# ID: 1387 , actual: T1090 , predicted: T1090
# ID: 1388 , actual: T1518 , predicted: T1518
# ID: 1389 , actual: T1218 , predicted: T1221
# ID: 1399 , actual: T1059 , predicted: T1064
# ID: 1412 , actual: T1132 , predicted: T1008
# ID: 1414 , actual: T1564 , predicted: T1143
# ID: 1415 , actual: T1574 , predicted: T1038
# ID: 1423 , actual: T1016 , predicted: T1016
# ID: 1426 , actual: T1036 , predicted: T1193
# ID: 1438 , actual: T1588 , predicted: T1046
# ID: 1454 , actual: T1204 , predicted: T1566
# ID: 1455 , actual: T1059 , predicted: T1064
# ID: 1456 , actual: T1564 , predicted: T1143
# ID: 1457 , actual: T1027 , predicted: T1497
# ID: 1461 , actual: T1218 , predicted: T1117
# ID: 1462 , actual: T1047 , predicted: T1047
# ID: 1468 , actual: T1543 , predicted: T1050
# ID: 1470 , actual: T1074 , predicted: T1022
# ID: 1479 , actual: T1082 , predicted: T1082
# ID: 1481 , actual: T1071 , predicted: T1105
# ID: 1491 , actual: T1083 , predicted: T1083
# ID: 1500 , actual: T1036 , predicted: T1050
# ID: 1510 , actual: T1021 , predicted: T1105
# ID: 1514 , actual: T1218 , predicted: T1085
# ID: 1515 , actual: T1016 , predicted: T1016
# ID: 1516 , actual: T1049 , predicted: T1049
# ID: 1524 , actual: T1560 , predicted: T1560
# ID: 1527 , actual: T1547 , predicted: T1060
# ID: 1530 , actual: T1059 , predicted: T1059
# ID: 1534 , actual: T1005 , predicted: T1005
# ID: 1537 , actual: T1573 , predicted: T1024
# ID: 1541 , actual: T1574 , predicted: T1055
# ID: 1548 , actual: T1070 , predicted: T1099
# ID: 1556 , actual: T1027 , predicted: T1027
# ID: 1564 , actual: T1057 , predicted: T1057
# ID: 1572 , actual: T1053 , predicted: T1053
# ID: 1574 , actual: T1218 , predicted: T1218
# ID: 1579 , actual: T1016 , predicted: T1016
# ID: 1581 , actual: T1033 , predicted: T1033
# ID: 1586 , actual: T1497 , predicted: T1497
# ID: 1590 , actual: T1074 , predicted: T1005
# ID: 1591 , actual: T1070 , predicted: T1070
# ID: 1598 , actual: T1021 , predicted: T1135
# ID: 1608 , actual: T1005 , predicted: T1005
# ID: 1616 , actual: T1036 , predicted: T1036
# ID: 1622 , actual: T1566 , predicted: T1193
# ID: 1625 , actual: T1021 , predicted: T1049
# ID: 1634 , actual: T1078 , predicted: T1078
# ID: 1643 , actual: T1059 , predicted: T1059
# ID: 1644 , actual: T1555 , predicted: T1003
# ID: 1645 , actual: T1105 , predicted: T1105
# ID: 1646 , actual: T1027 , predicted: T1027
# ID: 1652 , actual: T1553 , predicted: T1116
# ID: 1655 , actual: T1218 , predicted: T1085
# ID: 1657 , actual: T1204 , predicted: T1203
# ID: 1658 , actual: T1078 , predicted: T1078
# ID: 1667 , actual: T1078 , predicted: T1077
# ID: 1676 , actual: T1564 , predicted: T1105
# ID: 1684 , actual: T1566 , predicted: T1194
# ID: 1688 , actual: T1016 , predicted: T1016
# ID: 1711 , actual: T1090 , predicted: T1090
# ID: 1719 , actual: T1047 , predicted: T1047
# ID: 1723 , actual: T1204 , predicted: T1193
# ID: 1727 , actual: T1059 , predicted: T1064
# ID: 1734 , actual: T1053 , predicted: T1053
# ID: 1742 , actual: T1059 , predicted: T1059
# ID: 1743 , actual: T1083 , predicted: T1083
# ID: 1747 , actual: T1053 , predicted: T1053
# ID: 1749 , actual: T1078 , predicted: T1133
# ID: 1751 , actual: T1083 , predicted: T1083
# ID: 1752 , actual: T1027 , predicted: T1027
# ID: 1762 , actual: T1057 , predicted: T1057
# ID: 1767 , actual: T1033 , predicted: T1033
# ID: 1769 , actual: T1560 , predicted: T1560
# ID: 1776 , actual: T1140 , predicted: T1140
# ID: 1784 , actual: T1566 , predicted: T1193
# ID: 1786 , actual: T1055 , predicted: T1620
# ID: 1789 , actual: T1021 , predicted: T1018
# ID: 1801 , actual: T1560 , predicted: T1560
# ID: 1812 , actual: T1140 , predicted: T1140
# ID: 1813 , actual: T1573 , predicted: T1573
# ID: 1816 , actual: T1562 , predicted: T1107
# ID: 1820 , actual: T1070 , predicted: T1099
# ID: 1830 , actual: T1003 , predicted: T1078
# ID: 1831 , actual: T1069 , predicted: T1069
# ID: 1832 , actual: T1069 , predicted: T1069
# ID: 1834 , actual: T1566 , predicted: T1192
# ID: 1836 , actual: T1057 , predicted: T1057
# ID: 1838 , actual: T1090 , predicted: T1090
# ID: 1840 , actual: T1021 , predicted: T1076
# ID: 1844 , actual: T1053 , predicted: T1053
# ID: 1846 , actual: T1553 , predicted: T1036
# ID: 1853 , actual: T1078 , predicted: T1078
# ID: 1855 , actual: T1078 , predicted: T1078
# ID: 1857 , actual: T1102 , predicted: T1102
# ID: 1862 , actual: T1059 , predicted: T1059
# ID: 1870 , actual: T1070 , predicted: T1070
# ID: 1871 , actual: T1070 , predicted: T1070
# ID: 1889 , actual: T1027 , predicted: T1027
# ID: 1890 , actual: T1566 , predicted: T1566
# ID: 1892 , actual: T1204 , predicted: T1192
# ID: 1893 , actual: T1204 , predicted: T1193
# ID: 1894 , actual: T1059 , predicted: T1059
# ID: 1901 , actual: T1036 , predicted: T1189
# ID: 1913 , actual: T1105 , predicted: T1105
# ID: 1915 , actual: T1056 , predicted: T1179
# ID: 1917 , actual: T1003 , predicted: T1003
# ID: 1918 , actual: T1566 , predicted: T1193
# ID: 1922 , actual: T1071 , predicted: T1105
# ID: 1927 , actual: T1059 , predicted: T1086
# ID: 1929 , actual: T1059 , predicted: T1064
# ID: 1941 , actual: T1105 , predicted: T1105
# ID: 1943 , actual: T1036 , predicted: T1036
# ID: 1947 , actual: T1112 , predicted: T1112
# ID: 1953 , actual: T1566 , predicted: T1193
# ID: 1956 , actual: T1012 , predicted: T1012
# ID: 1958 , actual: T1018 , predicted: T1018
# ID: 1961 , actual: T1218 , predicted: T1117
# ID: 1962 , actual: T1218 , predicted: T1085
# ID: 1973 , actual: T1560 , predicted: T1560
# ID: 1978 , actual: T1555 , predicted: T1003
# ID: 1979 , actual: T1132 , predicted: T1001
# ID: 1983 , actual: T1574 , predicted: T1073
# ID: 1984 , actual: T1070 , predicted: T1107
# ID: 1986 , actual: T1036 , predicted: T1036
# ID: 1996 , actual: T1021 , predicted: T1076
# ID: 1998 , actual: T1518 , predicted: T1083
# ID: 2005 , actual: T1087 , predicted: T1087
# ID: 2007 , actual: T1059 , predicted: T1086
# ID: 2010 , actual: T1057 , predicted: T1057
# ID: 2018 , actual: T1053 , predicted: T1053
# ID: 2030 , actual: T1041 , predicted: T1041
# ID: 2031 , actual: T1562 , predicted: T1489
# ID: 2032 , actual: T1070 , predicted: T1107
# ID: 2039 , actual: T1003 , predicted: T1003
# ID: 2042 , actual: T1055 , predicted: T1055
# ID: 2044 , actual: T1021 , predicted: T1210
# ID: 2056 , actual: T1078 , predicted: T1078
# ID: 2060 , actual: T1059 , predicted: T1064
# ID: 2064 , actual: T1003 , predicted: T1003
# ID: 2068 , actual: T1036 , predicted: T1105
# ID: 2077 , actual: T1059 , predicted: T1059
# ID: 2082 , actual: T1566 , predicted: T1193
# ID: 2093 , actual: T1059 , predicted: T1064
# ID: 2096 , actual: T1074 , predicted: T1074
# ID: 2102 , actual: T1105 , predicted: T1105
# ID: 2104 , actual: T1036 , predicted: T1036
# ID: 2112 , actual: T1518 , predicted: T1518
# ID: 2123 , actual: T1547 , predicted: T1023
# ID: 2125 , actual: T1105 , predicted: T1105
# ID: 2132 , actual: T1057 , predicted: T1057
# ID: 2150 , actual: T1003 , predicted: T1003
# ID: 2151 , actual: T1518 , predicted: T1007
# ID: 2153 , actual: T1059 , predicted: T1119
# ID: 2163 , actual: T1140 , predicted: T1140
# ID: 2172 , actual: T1082 , predicted: T1082
# ID: 2173 , actual: T1016 , predicted: T1016
# ID: 2179 , actual: T1573 , predicted: T1027
# ID: 2183 , actual: T1069 , predicted: T1069
# ID: 2190 , actual: T1082 , predicted: T1082
# ID: 2197 , actual: T1005 , predicted: T1005
# ID: 2213 , actual: T1574 , predicted: T1038
# ID: 2215 , actual: T1553 , predicted: T1118
# ID: 2224 , actual: T1057 , predicted: T1057
# ID: 2229 , actual: T1005 , predicted: T1005
# ID: 2233 , actual: T1016 , predicted: T1016
# ID: 2236 , actual: T1547 , predicted: T1112
# ID: 2242 , actual: T1027 , predicted: T1027
# ID: 2243 , actual: T1012 , predicted: T1012
# ID: 2244 , actual: T1018 , predicted: T1018
# ID: 2248 , actual: T1112 , predicted: T1112
# ID: 2251 , actual: T1027 , predicted: T1027
# ID: 2253 , actual: T1102 , predicted: T1008
# ID: 2261 , actual: T1547 , predicted: T1112
# ID: 2263 , actual: T1105 , predicted: T1105
# ID: 2266 , actual: T1140 , predicted: T1140
# ID: 2268 , actual: T1027 , predicted: T1554
# ID: 2271 , actual: T1036 , predicted: T1036
# ID: 2286 , actual: T1059 , predicted: T1059
# ID: 2294 , actual: T1090 , predicted: T1090
# ID: 2304 , actual: T1555 , predicted: T1555
# ID: 2307 , actual: T1573 , predicted: T1573
# ID: 2309 , actual: T1106 , predicted: T1106
# ID: 2311 , actual: T1057 , predicted: T1057
# ID: 2312 , actual: T1055 , predicted: T1055
# ID: 2319 , actual: T1049 , predicted: T1049
# ID: 2329 , actual: T1059 , predicted: T1059
# ID: 2330 , actual: T1140 , predicted: T1140
# ID: 2335 , actual: T1140 , predicted: T1140
# ID: 2341 , actual: T1012 , predicted: T1012
# ID: 2347 , actual: T1569 , predicted: T1106
# ID: 2356 , actual: T1106 , predicted: T1106
# ID: 2373 , actual: T1033 , predicted: T1033
# ID: 2378 , actual: T1069 , predicted: T1069
# ID: 2379 , actual: T1018 , predicted: T1018
# ID: 2382 , actual: T1543 , predicted: T1159
# ID: 2394 , actual: T1036 , predicted: T1574
# ID: 2401 , actual: T1005 , predicted: T1005
# ID: 2402 , actual: T1074 , predicted: T1005
# ID: 2403 , actual: T1036 , predicted: T1050
# ID: 2407 , actual: T1543 , predicted: T1050
# ID: 2408 , actual: T1562 , predicted: T1089
# ID: 2413 , actual: T1105 , predicted: T1105
# ID: 2421 , actual: T1083 , predicted: T1083
# ID: 2424 , actual: T1055 , predicted: T1055
# ID: 2430 , actual: T1070 , predicted: T1126
# ID: 2437 , actual: T1124 , predicted: T1124
# ID: 2447 , actual: T1071 , predicted: T1094
# ID: 2454 , actual: T1059 , predicted: T1059
# ID: 2466 , actual: T1070 , predicted: T1041
# ID: 2471 , actual: T1036 , predicted: T1050
# ID: 2476 , actual: T1027 , predicted: T1027
# ID: 2477 , actual: T1057 , predicted: T1057
# ID: 2489 , actual: T1218 , predicted: T1050
# ID: 2492 , actual: T1016 , predicted: T1016
# ID: 2501 , actual: T1564 , predicted: T1158
# ID: 2502 , actual: T1056 , predicted: T1056
# ID: 2514 , actual: T1056 , predicted: T1056
# ID: 2520 , actual: T1090 , predicted: T1090
# ID: 2522 , actual: T1218 , predicted: T1085
# ID: 2532 , actual: T1132 , predicted: T1001
# ID: 2536 , actual: T1083 , predicted: T1083
# ID: 2538 , actual: T1070 , predicted: T1107
# ID: 2540 , actual: T1056 , predicted: T1056
# ID: 2543 , actual: T1003 , predicted: T1003
# ID: 2546 , actual: T1053 , predicted: T1053
# ID: 2550 , actual: T1033 , predicted: T1033
# ID: 2551 , actual: T1569 , predicted: T1050
# ID: 2555 , actual: T1497 , predicted: T1497
# ID: 2561 , actual: T1057 , predicted: T1057
# ID: 2571 , actual: T1059 , predicted: T1059
# ID: 2579 , actual: T1070 , predicted: T1485
# ID: 2580 , actual: T1105 , predicted: T1105
# ID: 2581 , actual: T1056 , predicted: T1056
# ID: 2586 , actual: T1012 , predicted: T1012
# ID: 2587 , actual: T1113 , predicted: T1113
# ID: 2588 , actual: T1218 , predicted: T1085
# ID: 2589 , actual: T1082 , predicted: T1082
# ID: 2591 , actual: T1071 , predicted: T1043
# ID: 2605 , actual: T1573 , predicted: T1573
# ID: 2609 , actual: T1105 , predicted: T1105
# ID: 2614 , actual: T1106 , predicted: T1106
# ID: 2616 , actual: T1027 , predicted: T1027
# ID: 2621 , actual: T1055 , predicted: T1055
# ID: 2624 , actual: T1053 , predicted: T1053
# ID: 2633 , actual: T1056 , predicted: T1056
# ID: 2636 , actual: T1070 , predicted: T1070
# ID: 2641 , actual: T1071 , predicted: T1043
# ID: 2642 , actual: T1560 , predicted: T1119
# ID: 2645 , actual: T1083 , predicted: T1083
# ID: 2646 , actual: T1564 , predicted: T1158
# ID: 2647 , actual: T1105 , predicted: T1105
# ID: 2651 , actual: T1518 , predicted: T1047
# ID: 2654 , actual: T1047 , predicted: T1047
# ID: 2656 , actual: T1083 , predicted: T1083
# ID: 2658 , actual: T1082 , predicted: T1082
# ID: 2659 , actual: T1059 , predicted: T1486
# ID: 2664 , actual: T1057 , predicted: T1057
# ID: 2668 , actual: T1016 , predicted: T1016
# ID: 2677 , actual: T1041 , predicted: T1041
# ID: 2691 , actual: T1005 , predicted: T1005
# ID: 2694 , actual: T1083 , predicted: T1083
# ID: 2704 , actual: T1033 , predicted: T1033
# ID: 2708 , actual: T1059 , predicted: T1086
# ID: 2709 , actual: T1059 , predicted: T1059
# ID: 2717 , actual: T1106 , predicted: T1106
# ID: 2718 , actual: T1027 , predicted: T1027
# ID: 2729 , actual: T1087 , predicted: T1087
# ID: 2732 , actual: T1059 , predicted: T1050
# ID: 2736 , actual: T1041 , predicted: T1041
# ID: 2739 , actual: T1112 , predicted: T1112
# ID: 2741 , actual: T1027 , predicted: T1027
# ID: 2755 , actual: T1071 , predicted: T1043
# ID: 2756 , actual: T1547 , predicted: T1060
# ID: 2757 , actual: T1059 , predicted: T1105
# ID: 2760 , actual: T1105 , predicted: T1105
# ID: 2761 , actual: T1053 , predicted: T1168
# ID: 2762 , actual: T1218 , predicted: T1170
# ID: 2765 , actual: T1102 , predicted: T1102
# ID: 2768 , actual: T1547 , predicted: T1112
# ID: 2769 , actual: T1059 , predicted: T1112
# ID: 2775 , actual: T1562 , predicted: T1112
# ID: 2785 , actual: T1082 , predicted: T1082
# ID: 2794 , actual: T1027 , predicted: T1027
# ID: 2798 , actual: T1071 , predicted: T1105
# ID: 2800 , actual: T1547 , predicted: T1060
# ID: 2805 , actual: T1070 , predicted: T1485
# ID: 2806 , actual: T1105 , predicted: T1105
# ID: 2813 , actual: T1560 , predicted: T1001
# ID: 2816 , actual: T1140 , predicted: T1140
# ID: 2824 , actual: T1071 , predicted: T1043
# ID: 2825 , actual: T1547 , predicted: T1204
# ID: 2827 , actual: T1547 , predicted: T1080
# ID: 2839 , actual: T1033 , predicted: T1033
# ID: 2840 , actual: T1071 , predicted: T1043
# ID: 2844 , actual: T1059 , predicted: T1059
# ID: 2852 , actual: T1562 , predicted: T1489
# ID: 2861 , actual: T1027 , predicted: T1027
# ID: 2869 , actual: T1553 , predicted: T1118
# ID: 2874 , actual: T1124 , predicted: T1124
# ID: 2876 , actual: T1497 , predicted: T1497
# ID: 2878 , actual: T1102 , predicted: T1105
# ID: 2884 , actual: T1140 , predicted: T1140
# ID: 2888 , actual: T1083 , predicted: T1083
# ID: 2891 , actual: T1562 , predicted: T1489
# ID: 2892 , actual: T1070 , predicted: T1070
# ID: 2900 , actual: T1027 , predicted: T1027
# ID: 2914 , actual: T1204 , predicted: T1203
# ID: 2916 , actual: T1102 , predicted: T1102
# ID: 2918 , actual: T1547 , predicted: T1023
# ID: 2922 , actual: T1083 , predicted: T1083
# ID: 2924 , actual: T1036 , predicted: T1112
# ID: 2932 , actual: T1132 , predicted: T1001
# ID: 2934 , actual: T1573 , predicted: T1032
# ID: 2937 , actual: T1574 , predicted: T1055
# ID: 2939 , actual: T1562 , predicted: T1146
# ID: 2941 , actual: T1553 , predicted: T1118
# ID: 2944 , actual: T1005 , predicted: T1005
# ID: 2952 , actual: T1055 , predicted: T1055
# ID: 2956 , actual: T1547 , predicted: T1112
# ID: 2967 , actual: T1071 , predicted: T1071
# ID: 2968 , actual: T1071 , predicted: T1568
# ID: 2981 , actual: T1070 , predicted: T1485
# ID: 2984 , actual: T1027 , predicted: T1027
# ID: 2985 , actual: T1027 , predicted: T1027
# ID: 2991 , actual: T1082 , predicted: T1082
# ID: 2995 , actual: T1071 , predicted: T1041
# ID: 3001 , actual: T1056 , predicted: T1056
# ID: 3020 , actual: T1071 , predicted: T1043
# ID: 3026 , actual: T1105 , predicted: T1105
# ID: 3027 , actual: T1027 , predicted: T1027
# ID: 3028 , actual: T1055 , predicted: T1055
# ID: 3029 , actual: T1055 , predicted: T1055
# ID: 3035 , actual: T1555 , predicted: T1555
# ID: 3044 , actual: T1543 , predicted: T1160
# ID: 3047 , actual: T1562 , predicted: T1057
# ID: 3051 , actual: T1106 , predicted: T1106
# ID: 3054 , actual: T1497 , predicted: T1497
# ID: 3056 , actual: T1071 , predicted: T1571
# ID: 3064 , actual: T1555 , predicted: T1555
# ID: 3070 , actual: T1070 , predicted: T1497
# ID: 3074 , actual: T1027 , predicted: T1027
# ID: 3080 , actual: T1082 , predicted: T1082
# ID: 3082 , actual: T1204 , predicted: T1193
# ID: 3084 , actual: T1071 , predicted: T1008
# ID: 3093 , actual: T1083 , predicted: T1083
# ID: 3094 , actual: T1574 , predicted: T1073
# ID: 3102 , actual: T1090 , predicted: T1090
# ID: 3113 , actual: T1070 , predicted: T1070
# ID: 3118 , actual: T1033 , predicted: T1033
# ID: 3125 , actual: T1105 , predicted: T1105
# ID: 3132 , actual: T1016 , predicted: T1016
# ID: 3150 , actual: T1560 , predicted: T1119
# ID: 3152 , actual: T1140 , predicted: T1140
# ID: 3153 , actual: T1083 , predicted: T1083
# ID: 3157 , actual: T1070 , predicted: T1107
# ID: 3161 , actual: T1071 , predicted: T1043
# ID: 3162 , actual: T1547 , predicted: T1112
# ID: 3165 , actual: T1005 , predicted: T1005
# ID: 3167 , actual: T1564 , predicted: T1158
# ID: 3189 , actual: T1574 , predicted: T1034
# ID: 3193 , actual: T1056 , predicted: T1056
# ID: 3198 , actual: T1055 , predicted: T1055
# ID: 3201 , actual: T1113 , predicted: T1113
# ID: 3213 , actual: T1027 , predicted: T1027
# ID: 3214 , actual: T1027 , predicted: T1027
# ID: 3221 , actual: T1049 , predicted: T1049
# ID: 3226 , actual: T1059 , predicted: T1059
# ID: 3234 , actual: T1070 , predicted: T1485
# ID: 3244 , actual: T1016 , predicted: T1016
# ID: 3254 , actual: T1018 , predicted: T1018
# ID: 3261 , actual: T1059 , predicted: T1206
# ID: 3263 , actual: T1555 , predicted: T1142
# ID: 3264 , actual: T1555 , predicted: T1003
# ID: 3267 , actual: T1562 , predicted: T1489
# ID: 3271 , actual: T1056 , predicted: T1141
# ID: 3278 , actual: T1543 , predicted: T1050
# ID: 3288 , actual: T1113 , predicted: T1113
# ID: 3295 , actual: T1036 , predicted: T1036
# ID: 3300 , actual: T1053 , predicted: T1053
# ID: 3303 , actual: T1497 , predicted: T1497
# ID: 3308 , actual: T1059 , predicted: T1059
# ID: 3321 , actual: T1113 , predicted: T1113
# ID: 3327 , actual: T1027 , predicted: T1027
# ID: 3328 , actual: T1090 , predicted: T1090
# ID: 3344 , actual: T1071 , predicted: T1041
# ID: 3352 , actual: T1070 , predicted: T1485
# ID: 3354 , actual: T1057 , predicted: T1057
# ID: 3358 , actual: T1057 , predicted: T1057
# ID: 3369 , actual: T1056 , predicted: T1056
# ID: 3379 , actual: T1071 , predicted: T1043
# ID: 3380 , actual: T1547 , predicted: T1112
# ID: 3383 , actual: T1074 , predicted: T1112
# ID: 3398 , actual: T1574 , predicted: T1073
# ID: 3408 , actual: T1059 , predicted: T1105
# ID: 3409 , actual: T1070 , predicted: T1107
# ID: 3412 , actual: T1057 , predicted: T1057
# ID: 3413 , actual: T1053 , predicted: T1053
# ID: 3425 , actual: T1543 , predicted: T1159
# ID: 3427 , actual: T1564 , predicted: T1158
# ID: 3430 , actual: T1105 , predicted: T1105
# ID: 3432 , actual: T1027 , predicted: T1027
# ID: 3440 , actual: T1105 , predicted: T1105
# ID: 3444 , actual: T1102 , predicted: T1008
# ID: 3454 , actual: T1497 , predicted: T1012
# ID: 3458 , actual: T1140 , predicted: T1140
# ID: 3466 , actual: T1082 , predicted: T1082
# ID: 3472 , actual: T1112 , predicted: T1112
# ID: 3473 , actual: T1518 , predicted: T1057
# ID: 3474 , actual: T1082 , predicted: T1082
# ID: 3475 , actual: T1497 , predicted: T1082
# ID: 3485 , actual: T1562 , predicted: T1176
# ID: 3488 , actual: T1036 , predicted: T1036
# ID: 3489 , actual: T1027 , predicted: T1027
# ID: 3494 , actual: T1059 , predicted: T1489
# ID: 3498 , actual: T1562 , predicted: T1112
# ID: 3502 , actual: T1027 , predicted: T1045
# ID: 3511 , actual: T1059 , predicted: T1162
# ID: 3523 , actual: T1005 , predicted: T1005
# ID: 3525 , actual: T1105 , predicted: T1105
# ID: 3527 , actual: T1082 , predicted: T1082
# ID: 3538 , actual: T1053 , predicted: T1088
# ID: 3540 , actual: T1204 , predicted: T1105
# ID: 3546 , actual: T1056 , predicted: T1056
# ID: 3552 , actual: T1547 , predicted: T1055
# ID: 3553 , actual: T1543 , predicted: T1050
# ID: 3555 , actual: T1070 , predicted: T1070
# ID: 3560 , actual: T1071 , predicted: T1043
# ID: 3564 , actual: T1005 , predicted: T1005
# ID: 3565 , actual: T1140 , predicted: T1140
# ID: 3581 , actual: T1204 , predicted: T1193
# ID: 3585 , actual: T1560 , predicted: T1560
# ID: 3596 , actual: T1016 , predicted: T1016
# ID: 3598 , actual: T1105 , predicted: T1105
# ID: 3612 , actual: T1140 , predicted: T1140
# ID: 3616 , actual: T1070 , predicted: T1485
# ID: 3618 , actual: T1106 , predicted: T1106
# ID: 3620 , actual: T1055 , predicted: T1106
# ID: 3632 , actual: T1070 , predicted: T1485
# ID: 3636 , actual: T1016 , predicted: T1016
# ID: 3637 , actual: T1569 , predicted: T1113
# ID: 3639 , actual: T1083 , predicted: T1083
# ID: 3642 , actual: T1057 , predicted: T1057
# ID: 3646 , actual: T1547 , predicted: T1112
# ID: 3647 , actual: T1059 , predicted: T1064
# ID: 3651 , actual: T1105 , predicted: T1105
# ID: 3652 , actual: T1027 , predicted: T1027
# ID: 3653 , actual: T1218 , predicted: T1170
# ID: 3655 , actual: T1016 , predicted: T1016
# ID: 3656 , actual: T1033 , predicted: T1033
# ID: 3657 , actual: T1071 , predicted: T1043
# ID: 3658 , actual: T1059 , predicted: T1059
# ID: 3659 , actual: T1140 , predicted: T1140
# ID: 3661 , actual: T1106 , predicted: T1106
# ID: 3668 , actual: T1547 , predicted: T1112
# ID: 3670 , actual: T1543 , predicted: T1050
# ID: 3678 , actual: T1112 , predicted: T1112
# ID: 3680 , actual: T1027 , predicted: T1027
# ID: 3683 , actual: T1547 , predicted: T1112
# ID: 3689 , actual: T1106 , predicted: T1106
# ID: 3701 , actual: T1059 , predicted: T1059
# ID: 3707 , actual: T1218 , predicted: T1085
# ID: 3711 , actual: T1059 , predicted: T1059
# ID: 3712 , actual: T1005 , predicted: T1005
# ID: 3713 , actual: T1027 , predicted: T1027
# ID: 3725 , actual: T1543 , predicted: T1112
# ID: 3726 , actual: T1140 , predicted: T1140
# ID: 3734 , actual: T1027 , predicted: T1027
# ID: 3736 , actual: T1090 , predicted: T1090
# ID: 3741 , actual: T1547 , predicted: T1112
# ID: 3744 , actual: T1132 , predicted: T1001
# ID: 3745 , actual: T1105 , predicted: T1105
# ID: 3751 , actual: T1218 , predicted: T1170
# ID: 3755 , actual: T1102 , predicted: T1102
# ID: 3760 , actual: T1071 , predicted: T1071
# ID: 3762 , actual: T1560 , predicted: T1560
# ID: 3770 , actual: T1105 , predicted: T1105
# ID: 3772 , actual: T1027 , predicted: T1027
# ID: 3777 , actual: T1047 , predicted: T1047
# ID: 3781 , actual: T1059 , predicted: T1059
# ID: 3784 , actual: T1105 , predicted: T1105
# ID: 3791 , actual: T1082 , predicted: T1082
# ID: 3792 , actual: T1033 , predicted: T1033
# ID: 3806 , actual: T1082 , predicted: T1082
# ID: 3813 , actual: T1036 , predicted: T1027
# ID: 3815 , actual: T1106 , predicted: T1106
# ID: 3823 , actual: T1124 , predicted: T1124
# ID: 3827 , actual: T1059 , predicted: T1059
# ID: 3832 , actual: T1083 , predicted: T1083
# ID: 3841 , actual: T1027 , predicted: T1129
# ID: 3850 , actual: T1140 , predicted: T1140
# ID: 3851 , actual: T1573 , predicted: T1571
# ID: 3853 , actual: T1106 , predicted: T1106
# ID: 3856 , actual: T1124 , predicted: T1124
# ID: 3859 , actual: T1059 , predicted: T1059
# ID: 3863 , actual: T1113 , predicted: T1113
# ID: 3866 , actual: T1071 , predicted: T1571
# ID: 3880 , actual: T1059 , predicted: T1059
# ID: 3885 , actual: T1053 , predicted: T1168
# ID: 3895 , actual: T1070 , predicted: T1485
# ID: 3897 , actual: T1027 , predicted: T1027
# ID: 3907 , actual: T1059 , predicted: T1059
# ID: 3908 , actual: T1059 , predicted: T1193
# ID: 3915 , actual: T1564 , predicted: T1143
# ID: 3922 , actual: T1057 , predicted: T1057
# ID: 3928 , actual: T1016 , predicted: T1016
# ID: 3932 , actual: T1102 , predicted: T1102
# ID: 3940 , actual: T1003 , predicted: T1003
# ID: 3944 , actual: T1555 , predicted: T1503
# ID: 3951 , actual: T1218 , predicted: T1105
# ID: 3952 , actual: T1204 , predicted: T1189
# ID: 3955 , actual: T1059 , predicted: T1059
# ID: 3965 , actual: T1112 , predicted: T1112
# ID: 3975 , actual: T1112 , predicted: T1112
# ID: 3976 , actual: T1021 , predicted: T1076
# ID: 3978 , actual: T1053 , predicted: T1053
# ID: 3994 , actual: T1070 , predicted: T1070
# ID: 4009 , actual: T1056 , predicted: T1056
# ID: 4014 , actual: T1012 , predicted: T1012
# ID: 4017 , actual: T1016 , predicted: T1016
# ID: 4025 , actual: T1105 , predicted: T1105
# ID: 4033 , actual: T1059 , predicted: T1105
# ID: 4046 , actual: T1113 , predicted: T1113
# ID: 4047 , actual: T1518 , predicted: T1063
# ID: 4056 , actual: T1105 , predicted: T1105
# ID: 4060 , actual: T1069 , predicted: T1033
# ID: 4062 , actual: T1057 , predicted: T1057
# ID: 4064 , actual: T1018 , predicted: T1018
# ID: 4065 , actual: T1218 , predicted: T1112
# ID: 4071 , actual: T1547 , predicted: T1547
# ID: 4084 , actual: T1057 , predicted: T1057
# ID: 4087 , actual: T1082 , predicted: T1082
# ID: 4089 , actual: T1049 , predicted: T1049
# ID: 4090 , actual: T1078 , predicted: T1078
# ID: 4093 , actual: T1059 , predicted: T1112
# ID: 4099 , actual: T1016 , predicted: T1016
# ID: 4101 , actual: T1071 , predicted: T1041
# ID: 4102 , actual: T1547 , predicted: T1112
# ID: 4106 , actual: T1027 , predicted: T1027
# ID: 4107 , actual: T1027 , predicted: T1027
# ID: 4110 , actual: T1071 , predicted: T1043
# ID: 4111 , actual: T1071 , predicted: T1041
# ID: 4112 , actual: T1547 , predicted: T1112
# ID: 4116 , actual: T1027 , predicted: T1027
# ID: 4124 , actual: T1005 , predicted: T1005
# ID: 4128 , actual: T1041 , predicted: T1041
# ID: 4139 , actual: T1033 , predicted: T1033
# ID: 4141 , actual: T1087 , predicted: T1033
# ID: 4146 , actual: T1543 , predicted: T1067
# ID: 4149 , actual: T1573 , predicted: T1094
# ID: 4157 , actual: T1106 , predicted: T1106
# ID: 4161 , actual: T1012 , predicted: T1012
# ID: 4167 , actual: T1082 , predicted: T1082
# ID: 4168 , actual: T1016 , predicted: T1016
# ID: 4179 , actual: T1005 , predicted: T1005
# ID: 4197 , actual: T1573 , predicted: T1032
# ID: 4198 , actual: T1041 , predicted: T1041
# ID: 4201 , actual: T1059 , predicted: T1059
# ID: 4203 , actual: T1140 , predicted: T1140
# ID: 4214 , actual: T1070 , predicted: T1070
# ID: 4215 , actual: T1070 , predicted: T1485
# ID: 4217 , actual: T1112 , predicted: T1112
# ID: 4219 , actual: T1057 , predicted: T1057
# ID: 4227 , actual: T1059 , predicted: T1059
# ID: 4229 , actual: T1005 , predicted: T1005
# ID: 4231 , actual: T1573 , predicted: T1024
# ID: 4236 , actual: T1112 , predicted: T1112
# ID: 4245 , actual: T1102 , predicted: T1102
# ID: 4251 , actual: T1083 , predicted: T1083
# ID: 4255 , actual: T1036 , predicted: T1116
# ID: 4256 , actual: T1106 , predicted: T1106
# ID: 4258 , actual: T1124 , predicted: T1124
# ID: 4267 , actual: T1518 , predicted: T1063
# ID: 4283 , actual: T1071 , predicted: T1043
# ID: 4286 , actual: T1547 , predicted: T1023
# ID: 4303 , actual: T1071 , predicted: T1571
# ID: 4304 , actual: T1547 , predicted: T1112
# ID: 4310 , actual: T1083 , predicted: T1083
# ID: 4317 , actual: T1053 , predicted: T1053
# ID: 4319 , actual: T1218 , predicted: T1117
# ID: 4321 , actual: T1082 , predicted: T1082
# ID: 4338 , actual: T1102 , predicted: T1102
# ID: 4339 , actual: T1560 , predicted: T1560
# ID: 4340 , actual: T1059 , predicted: T1059
# ID: 4345 , actual: T1112 , predicted: T1112
# ID: 4349 , actual: T1140 , predicted: T1140
# ID: 4360 , actual: T1033 , predicted: T1033
# ID: 4361 , actual: T1547 , predicted: T1023
# ID: 4365 , actual: T1005 , predicted: T1005
# ID: 4380 , actual: T1113 , predicted: T1113
# ID: 4382 , actual: T1082 , predicted: T1082
# ID: 4383 , actual: T1124 , predicted: T1124
# ID: 4391 , actual: T1070 , predicted: T1070
# ID: 4393 , actual: T1056 , predicted: T1055
# ID: 4394 , actual: T1036 , predicted: T1036
# ID: 4395 , actual: T1027 , predicted: T1027
# ID: 4400 , actual: T1124 , predicted: T1124
# ID: 4401 , actual: T1071 , predicted: T1043
# ID: 4412 , actual: T1112 , predicted: T1112
# ID: 4419 , actual: T1124 , predicted: T1124
# ID: 4429 , actual: T1112 , predicted: T1112
# ID: 4432 , actual: T1012 , predicted: T1012
# ID: 4434 , actual: T1059 , predicted: T1055
# ID: 4435 , actual: T1140 , predicted: T1140
# ID: 4444 , actual: T1005 , predicted: T1005
# ID: 4460 , actual: T1083 , predicted: T1083
# ID: 4473 , actual: T1497 , predicted: T1029
# ID: 4475 , actual: T1059 , predicted: T1059
# ID: 4478 , actual: T1070 , predicted: T1099
# ID: 4489 , actual: T1112 , predicted: T1112
# ID: 4491 , actual: T1027 , predicted: T1140
# ID: 4493 , actual: T1012 , predicted: T1012
# ID: 4496 , actual: T1124 , predicted: T1124
# ID: 4503 , actual: T1112 , predicted: T1112
# ID: 4508 , actual: T1033 , predicted: T1033
# ID: 4509 , actual: T1059 , predicted: T1059
# ID: 4513 , actual: T1218 , predicted: T1047
# ID: 4522 , actual: T1074 , predicted: T1005
# ID: 4524 , actual: T1083 , predicted: T1083
# ID: 4526 , actual: T1036 , predicted: T1036
# ID: 4529 , actual: T1082 , predicted: T1082
# ID: 4531 , actual: T1033 , predicted: T1033
# ID: 4537 , actual: T1071 , predicted: T1041
# ID: 4550 , actual: T1036 , predicted: T1050
# ID: 4555 , actual: T1071 , predicted: T1043
# ID: 4557 , actual: T1059 , predicted: T1059
# ID: 4560 , actual: T1070 , predicted: T1070
# ID: 4562 , actual: T1027 , predicted: T1027
# ID: 4564 , actual: T1071 , predicted: T1043
# ID: 4575 , actual: T1027 , predicted: T1497
# ID: 4578 , actual: T1553 , predicted: T1649
# ID: 4582 , actual: T1059 , predicted: T1064
# ID: 4583 , actual: T1132 , predicted: T1001
# ID: 4584 , actual: T1005 , predicted: T1005
# ID: 4586 , actual: T1070 , predicted: T1070
# ID: 4587 , actual: T1105 , predicted: T1105
# ID: 4597 , actual: T1033 , predicted: T1033
# ID: 4599 , actual: T1071 , predicted: T1043
# ID: 4609 , actual: T1106 , predicted: T1106
# ID: 4611 , actual: T1069 , predicted: T1069
# ID: 4618 , actual: T1204 , predicted: T1193
# ID: 4626 , actual: T1070 , predicted: T1070
# ID: 4631 , actual: T1069 , predicted: T1069
# ID: 4635 , actual: T1016 , predicted: T1016
# ID: 4638 , actual: T1204 , predicted: T1193
# ID: 4640 , actual: T1059 , predicted: T1105
# ID: 4642 , actual: T1059 , predicted: T1047
# ID: 4643 , actual: T1140 , predicted: T1140
# ID: 4669 , actual: T1543 , predicted: T1050
# ID: 4673 , actual: T1574 , predicted: T1038
# ID: 4677 , actual: T1027 , predicted: T1027
# ID: 4678 , actual: T1027 , predicted: T1140
# ID: 4679 , actual: T1113 , predicted: T1113
# ID: 4682 , actual: T1047 , predicted: T1047
# ID: 4696 , actual: T1102 , predicted: T1105
# ID: 4697 , actual: T1564 , predicted: T1067
# ID: 4716 , actual: T1518 , predicted: T1518
# ID: 4717 , actual: T1059 , predicted: T1059
# ID: 4720 , actual: T1071 , predicted: T1094
# ID: 4722 , actual: T1059 , predicted: T1059
# ID: 4731 , actual: T1053 , predicted: T1053
# ID: 4732 , actual: T1553 , predicted: T1553
# ID: 4738 , actual: T1057 , predicted: T1057
# ID: 4745 , actual: T1105 , predicted: T1105
# ID: 4750 , actual: T1074 , predicted: T1083
# ID: 4751 , actual: T1070 , predicted: T1070
# ID: 4753 , actual: T1027 , predicted: T1027
# ID: 4781 , actual: T1071 , predicted: T1008
# ID: 4783 , actual: T1555 , predicted: T1555
# ID: 4793 , actual: T1087 , predicted: T1033
# ID: 4795 , actual: T1059 , predicted: T1064
# ID: 4798 , actual: T1036 , predicted: T1036
# ID: 4799 , actual: T1106 , predicted: T1106
# ID: 4800 , actual: T1027 , predicted: T1027
# ID: 4801 , actual: T1566 , predicted: T1193
# ID: 4803 , actual: T1082 , predicted: T1082
# ID: 4805 , actual: T1204 , predicted: T1189
# ID: 4809 , actual: T1059 , predicted: T1059
# ID: 4814 , actual: T1113 , predicted: T1113
# ID: 4818 , actual: T1059 , predicted: T1059
# ID: 4824 , actual: T1027 , predicted: T1027
# ID: 4827 , actual: T1547 , predicted: T1112
# ID: 4828 , actual: T1059 , predicted: T1059
# ID: 4832 , actual: T1005 , predicted: T1005
# ID: 4833 , actual: T1140 , predicted: T1140
# ID: 4835 , actual: T1041 , predicted: T1041
# ID: 4839 , actual: T1036 , predicted: T1036
# ID: 4841 , actual: T1112 , predicted: T1112
# ID: 4843 , actual: T1027 , predicted: T1027
# ID: 4847 , actual: T1057 , predicted: T1057
# ID: 4849 , actual: T1012 , predicted: T1012
# ID: 4854 , actual: T1204 , predicted: T1193
# ID: 4856 , actual: T1497 , predicted: T1497
# ID: 4861 , actual: T1140 , predicted: T1140
# ID: 4862 , actual: T1573 , predicted: T1032
# ID: 4866 , actual: T1112 , predicted: T1112
# ID: 4873 , actual: T1016 , predicted: T1016
# ID: 4881 , actual: T1059 , predicted: T1105
# ID: 4882 , actual: T1059 , predicted: T1059
# ID: 4900 , actual: T1047 , predicted: T1047
# ID: 4905 , actual: T1564 , predicted: T1036
# ID: 4909 , actual: T1071 , predicted: T1571
# ID: 4912 , actual: T1074 , predicted: T1074
# ID: 4916 , actual: T1056 , predicted: T1056
# ID: 4930 , actual: T1018 , predicted: T1018
# ID: 4937 , actual: T1547 , predicted: T1060
# ID: 4939 , actual: T1555 , predicted: T1555
# ID: 4943 , actual: T1083 , predicted: T1083
# ID: 4945 , actual: T1070 , predicted: T1485
# ID: 4946 , actual: T1056 , predicted: T1010
# ID: 4948 , actual: T1113 , predicted: T1113
# ID: 4949 , actual: T1518 , predicted: T1063
# ID: 4955 , actual: T1027 , predicted: T1027
# ID: 4958 , actual: T1547 , predicted: T1112
# ID: 4961 , actual: T1083 , predicted: T1083
# ID: 4964 , actual: T1112 , predicted: T1112
# ID: 4966 , actual: T1055 , predicted: T1055
# ID: 4975 , actual: T1140 , predicted: T1140
# ID: 4983 , actual: T1140 , predicted: T1140
# ID: 4995 , actual: T1070 , predicted: T1485
# ID: 4997 , actual: T1036 , predicted: T1036
# ID: 5000 , actual: T1082 , predicted: T1082
# ID: 5015 , actual: T1033 , predicted: T1033
# ID: 5017 , actual: T1071 , predicted: T1095
# ID: 5023 , actual: T1057 , predicted: T1057
# ID: 5024 , actual: T1012 , predicted: T1012
# ID: 5032 , actual: T1083 , predicted: T1083
# ID: 5034 , actual: T1574 , predicted: T1073
# ID: 5035 , actual: T1574 , predicted: T1149
# ID: 5041 , actual: T1027 , predicted: T1045
# ID: 5053 , actual: T1027 , predicted: T1036
# ID: 5060 , actual: T1566 , predicted: T1192
# ID: 5061 , actual: T1018 , predicted: T1018
# ID: 5065 , actual: T1082 , predicted: T1082
# ID: 5070 , actual: T1543 , predicted: T1050
# ID: 5077 , actual: T1056 , predicted: T1056
# ID: 5092 , actual: T1140 , predicted: T1140
# ID: 5094 , actual: T1041 , predicted: T1041
# ID: 5096 , actual: T1562 , predicted: T1489
# ID: 5099 , actual: T1105 , predicted: T1105
# ID: 5110 , actual: T1047 , predicted: T1047
# ID: 5115 , actual: T1036 , predicted: T1047
# ID: 5118 , actual: T1003 , predicted: T1003
# ID: 5122 , actual: T1082 , predicted: T1082
# ID: 5125 , actual: T1071 , predicted: T1043
# ID: 5130 , actual: T1082 , predicted: T1082
# ID: 5162 , actual: T1047 , predicted: T1047
# ID: 5167 , actual: T1057 , predicted: T1057
# ID: 5169 , actual: T1082 , predicted: T1082
# ID: 5171 , actual: T1204 , predicted: T1203
# ID: 5175 , actual: T1057 , predicted: T1057
# ID: 5176 , actual: T1082 , predicted: T1082
# ID: 5177 , actual: T1204 , predicted: T1193
# ID: 5178 , actual: T1087 , predicted: T1033
# ID: 5179 , actual: T1071 , predicted: T1571
# ID: 5191 , actual: T1055 , predicted: T1055
# ID: 5198 , actual: T1033 , predicted: T1033
# ID: 5206 , actual: T1059 , predicted: T1059
# ID: 5207 , actual: T1059 , predicted: T1059
# ID: 5212 , actual: T1573 , predicted: T1027
# ID: 5216 , actual: T1562 , predicted: T1497
# ID: 5217 , actual: T1070 , predicted: T1099
# ID: 5219 , actual: T1056 , predicted: T1056
# ID: 5228 , actual: T1057 , predicted: T1057
# ID: 5238 , actual: T1021 , predicted: T1133
# ID: 5247 , actual: T1569 , predicted: T1059
# ID: 5255 , actual: T1059 , predicted: T1059
# ID: 5256 , actual: T1059 , predicted: T1059
# ID: 5258 , actual: T1070 , predicted: T1070
# ID: 5259 , actual: T1105 , predicted: T1105
# ID: 5267 , actual: T1027 , predicted: T1027
# ID: 5277 , actual: T1082 , predicted: T1082
# ID: 5279 , actual: T1033 , predicted: T1033
# ID: 5287 , actual: T1053 , predicted: T1168
# ID: 5288 , actual: T1113 , predicted: T1113
# ID: 5293 , actual: T1090 , predicted: T1090
# ID: 5301 , actual: T1005 , predicted: T1005
# ID: 5315 , actual: T1082 , predicted: T1082
# ID: 5322 , actual: T1102 , predicted: T1102
# ID: 5326 , actual: T1083 , predicted: T1083
# ID: 5329 , actual: T1113 , predicted: T1113
# ID: 5330 , actual: T1547 , predicted: T1112
# ID: 5334 , actual: T1070 , predicted: T1485
# ID: 5339 , actual: T1082 , predicted: T1082
# ID: 5349 , actual: T1027 , predicted: T1027
# ID: 5351 , actual: T1218 , predicted: T1085
# ID: 5357 , actual: T1087 , predicted: T1033
# ID: 5359 , actual: T1069 , predicted: T1033
# ID: 5364 , actual: T1049 , predicted: T1049
# ID: 5366 , actual: T1560 , predicted: T1560
# ID: 5367 , actual: T1547 , predicted: T1060
# ID: 5372 , actual: T1112 , predicted: T1112
# ID: 5373 , actual: T1027 , predicted: T1140
# ID: 5379 , actual: T1016 , predicted: T1016
# ID: 5380 , actual: T1033 , predicted: T1033
# ID: 5387 , actual: T1036 , predicted: T1060
# ID: 5398 , actual: T1070 , predicted: T1485
# ID: 5413 , actual: T1573 , predicted: T1027
# ID: 5414 , actual: T1041 , predicted: T1041
# ID: 5417 , actual: T1070 , predicted: T1485
# ID: 5419 , actual: T1056 , predicted: T1056
# ID: 5420 , actual: T1036 , predicted: T1036
# ID: 5424 , actual: T1027 , predicted: T1009
# ID: 5426 , actual: T1027 , predicted: T1009
# ID: 5427 , actual: T1069 , predicted: T1069
# ID: 5434 , actual: T1018 , predicted: T1018
# ID: 5436 , actual: T1518 , predicted: T1518
# ID: 5452 , actual: T1047 , predicted: T1047
# ID: 5460 , actual: T1124 , predicted: T1124
# ID: 5469 , actual: T1036 , predicted: T1036
# ID: 5487 , actual: T1112 , predicted: T1112
# ID: 5496 , actual: T1033 , predicted: T1033
# ID: 5517 , actual: T1053 , predicted: T1053
# ID: 5526 , actual: T1047 , predicted: T1047
# ID: 5544 , actual: T1003 , predicted: T1003
# ID: 5554 , actual: T1059 , predicted: T1059
# ID: 5560 , actual: T1057 , predicted: T1057
# ID: 5563 , actual: T1113 , predicted: T1113
# ID: 5566 , actual: T1016 , predicted: T1016
# ...
# ID: 6556 , actual: T1140 , predicted: T1140
# ID: 6564 , actual: T1124 , predicted: T1124
# ID: 6567 , actual: T1059 , predicted: T1156
# ID: 6569 , actual: T1543 , predicted: T1160
# ID: 6571 , actual: T1041 , predicted: T1041
# ID: 6572 , actual: T1564 , predicted: T1036
# ID: 6577 , actual: T1553 , predicted: T1116
# ID: 6581 , actual: T1204 , predicted: T1192
# ID: 6584 , actual: T1071 , predicted: T1043
# ID: 6594 , actual: T1012 , predicted: T1012
# ID: 6602 , actual: T1083 , predicted: T1083
# ID: 6606 , actual: T1027 , predicted: T1027
# ID: 6607 , actual: T1027 , predicted: T1044
# ID: 6610 , actual: T1021 , predicted: T1076
# ID: 6618 , actual: T1573 , predicted: T1560
# ID: 6632 , actual: T1041 , predicted: T1041
# ID: 6636 , actual: T1105 , predicted: T1105
# ID: 6642 , actual: T1016 , predicted: T1016
# ID: 6643 , actual: T1071 , predicted: T1043
# ID: 6645 , actual: T1059 , predicted: T1059
# ID: 6646 , actual: T1041 , predicted: T1041
# ID: 6649 , actual: T1027 , predicted: T1140
# ID: 6650 , actual: T1082 , predicted: T1082
# ID: 6662 , actual: T1543 , predicted: T1050
# ID: 6672 , actual: T1547 , predicted: T1060
# ID: 6677 , actual: T1140 , predicted: T1140
# ID: 6681 , actual: T1113 , predicted: T1113
# ID: 6682 , actual: T1518 , predicted: T1057
# ID: 6683 , actual: T1218 , predicted: T1117
# ID: 6691 , actual: T1547 , predicted: T1060
# ID: 6693 , actual: T1059 , predicted: T1220
# ID: 6694 , actual: T1074 , predicted: T1083
# ID: 6699 , actual: T1105 , predicted: T1105
# ID: 6701 , actual: T1027 , predicted: T1106
# ID: 6703 , actual: T1113 , predicted: T1113
# ID: 6713 , actual: T1041 , predicted: T1041
# ID: 6717 , actual: T1082 , predicted: T1082
# ID: 6718 , actual: T1016 , predicted: T1016
# ID: 6725 , actual: T1543 , predicted: T1112
# ID: 6726 , actual: T1555 , predicted: T1555
# ID: 6727 , actual: T1083 , predicted: T1083
# ID: 6731 , actual: T1056 , predicted: T1056
# ID: 6751 , actual: T1070 , predicted: T1064
# ID: 6752 , actual: T1105 , predicted: T1105
# ID: 6753 , actual: T1036 , predicted: T1053
# ID: 6754 , actual: T1036 , predicted: T1036
# ID: 6760 , actual: T1057 , predicted: T1057
# ID: 6761 , actual: T1055 , predicted: T1055
# ID: 6764 , actual: T1012 , predicted: T1012
# ID: 6771 , actual: T1016 , predicted: T1016
# ID: 6774 , actual: T1204 , predicted: T1189
# ID: 6783 , actual: T1070 , predicted: T1485
# ID: 6792 , actual: T1124 , predicted: T1124
# ID: 6795 , actual: T1555 , predicted: T1555
# ID: 6801 , actual: T1204 , predicted: T1189
# ID: 6814 , actual: T1132 , predicted: T1001
# ID: 6816 , actual: T1140 , predicted: T1140
# ID: 6817 , actual: T1573 , predicted: T1032
# ID: 6821 , actual: T1036 , predicted: T1007
# ID: 6824 , actual: T1113 , predicted: T1113
# ID: 6840 , actual: T1543 , predicted: T1031
# ID: 6842 , actual: T1074 , predicted: T1074
# ID: 6843 , actual: T1573 , predicted: T1573
# ID: 6849 , actual: T1059 , predicted: T1059
# ID: 6857 , actual: T1012 , predicted: T1012
# ID: 6860 , actual: T1140 , predicted: T1140
# ID: 6870 , actual: T1547 , predicted: T1112
# ID: 6878 , actual: T1573 , predicted: T1027
# ID: 6900 , actual: T1036 , predicted: T1127
# ID: 6904 , actual: T1053 , predicted: T1053
# ID: 6920 , actual: T1027 , predicted: T1027
# ID: 6921 , actual: T1027 , predicted: T1045
# ID: 6932 , actual: T1070 , predicted: T1485
# ID: 6933 , actual: T1105 , predicted: T1105
# ID: 6934 , actual: T1056 , predicted: T1056
# ID: 6938 , actual: T1027 , predicted: T1027
# ID: 6939 , actual: T1057 , predicted: T1057
# ID: 6945 , actual: T1071 , predicted: T1095
# ID: 6946 , actual: T1547 , predicted: T1215
# ID: 6956 , actual: T1560 , predicted: T1560
# ID: 6957 , actual: T1560 , predicted: T1027
# ID: 6959 , actual: T1140 , predicted: T1140
# ID: 6969 , actual: T1027 , predicted: T1105
# ID: 6971 , actual: T1071 , predicted: T1041
# ID: 6980 , actual: T1105 , predicted: T1105
# ID: 6985 , actual: T1027 , predicted: T1105
# ID: 6988 , actual: T1543 , predicted: T1050
# ID: 6994 , actual: T1059 , predicted: T1059
# ID: 6995 , actual: T1555 , predicted: T1555
# ID: 7006 , actual: T1106 , predicted: T1106
# ID: 7017 , actual: T1069 , predicted: T1033
# ID: 7018 , actual: T1082 , predicted: T1082
# ID: 7028 , actual: T1071 , predicted: T1043
# ID: 7029 , actual: T1547 , predicted: T1060
# ID: 7030 , actual: T1547 , predicted: T1060
# ID: 7032 , actual: T1555 , predicted: T1003
# ID: 7033 , actual: T1573 , predicted: T1032
# ID: 7038 , actual: T1027 , predicted: T1027
# ID: 7042 , actual: T1049 , predicted: T1049
# ID: 7043 , actual: T1033 , predicted: T1033
# ID: 7044 , actual: T1087 , predicted: T1114
# ID: 7045 , actual: T1560 , predicted: T1560
# ID: 7046 , actual: T1547 , predicted: T1112
# ID: 7053 , actual: T1055 , predicted: T1055
# ID: 7055 , actual: T1218 , predicted: T1085
# ID: 7060 , actual: T1059 , predicted: T1059
# ID: 7061 , actual: T1543 , predicted: T1496
# ID: 7062 , actual: T1140 , predicted: T1140
# ID: 7064 , actual: T1562 , predicted: T1568
# ID: 7070 , actual: T1027 , predicted: T1027
# ID: 7078 , actual: T1083 , predicted: T1083
# ID: 7083 , actual: T1057 , predicted: T1057
# ID: 7089 , actual: T1033 , predicted: T1033
# ID: 7091 , actual: T1497 , predicted: T1124
# ID: 7093 , actual: T1078 , predicted: T1098
# ID: 7100 , actual: T1562 , predicted: T1489
# ID: 7101 , actual: T1070 , predicted: T1070
# ID: 7108 , actual: T1071 , predicted: T1043
# ID: 7114 , actual: T1562 , predicted: T1489
# ID: 7118 , actual: T1105 , predicted: T1105
# ID: 7128 , actual: T1021 , predicted: T1219
# ID: 7129 , actual: T1113 , predicted: T1113
# ID: 7130 , actual: T1218 , predicted: T1085
# ID: 7135 , actual: T1071 , predicted: T1043
# ID: 7139 , actual: T1105 , predicted: T1105
# ID: 7140 , actual: T1112 , predicted: T1112
# ID: 7141 , actual: T1027 , predicted: T1027
# ID: 7144 , actual: T1553 , predicted: T1068
# ID: 7145 , actual: T1569 , predicted: T1050
# ID: 7156 , actual: T1005 , predicted: T1005
# ID: 7165 , actual: T1036 , predicted: T1036
# ID: 7166 , actual: T1112 , predicted: T1112
# ID: 7177 , actual: T1033 , predicted: T1033
# ID: 7178 , actual: T1204 , predicted: T1193
# ID: 7181 , actual: T1027 , predicted: T1027
# ID: 7187 , actual: T1105 , predicted: T1105
# ID: 7197 , actual: T1053 , predicted: T1529
# ID: 7198 , actual: T1518 , predicted: T1063
# ID: 7206 , actual: T1071 , predicted: T1043
# ID: 7209 , actual: T1070 , predicted: T1099
# ID: 7211 , actual: T1547 , predicted: T1112
# ID: 7212 , actual: T1059 , predicted: T1059
# ID: 7217 , actual: T1003 , predicted: T1006
# ID: 7220 , actual: T1543 , predicted: T1050
# ID: 7224 , actual: T1105 , predicted: T1105
# ID: 7225 , actual: T1036 , predicted: T1112
# ID: 7228 , actual: T1082 , predicted: T1082
# ID: 7231 , actual: T1560 , predicted: T1560
# ID: 7244 , actual: T1027 , predicted: T1027
# ID: 7245 , actual: T1027 , predicted: T1036
# ID: 7250 , actual: T1113 , predicted: T1113
# ID: 7253 , actual: T1049 , predicted: T1049
# ID: 7259 , actual: T1105 , predicted: T1105
# ID: 7266 , actual: T1059 , predicted: T1005
# ID: 7282 , actual: T1033 , predicted: T1033
# ID: 7284 , actual: T1071 , predicted: T1043
# ID: 7285 , actual: T1132 , predicted: T1001
# ID: 7288 , actual: T1105 , predicted: T1105
# ID: 7293 , actual: T1016 , predicted: T1016
# ID: 7305 , actual: T1071 , predicted: T1071
# ID: 7306 , actual: T1560 , predicted: T1027
# ID: 7310 , actual: T1070 , predicted: T1107
# ID: 7313 , actual: T1218 , predicted: T1085
# ID: 7315 , actual: T1016 , predicted: T1016
# ID: 7321 , actual: T1003 , predicted: T1003
# ID: 7329 , actual: T1102 , predicted: T1102
# ID: 7332 , actual: T1140 , predicted: T1140
# ID: 7339 , actual: T1555 , predicted: T1555
# ID: 7349 , actual: T1036 , predicted: T1036
# ID: 7352 , actual: T1082 , predicted: T1082
# ID: 7354 , actual: T1087 , predicted: T1033
# ID: 7355 , actual: T1059 , predicted: T1059
# ID: 7356 , actual: T1070 , predicted: T1485
# ID: 7359 , actual: T1053 , predicted: T1053
# ID: 7364 , actual: T1573 , predicted: T1027
# ID: 7369 , actual: T1033 , predicted: T1033
# ID: 7372 , actual: T1105 , predicted: T1105
# ID: 7387 , actual: T1056 , predicted: T1056
# ID: 7393 , actual: T1083 , predicted: T1083
# ID: 7398 , actual: T1057 , predicted: T1057
# ID: 7401 , actual: T1218 , predicted: T1218
# ID: 7404 , actual: T1105 , predicted: T1105
# ID: 7405 , actual: T1112 , predicted: T1050
# ID: 7420 , actual: T1016 , predicted: T1016
# ID: 7430 , actual: T1018 , predicted: T1018
# ID: 7433 , actual: T1059 , predicted: T1064
# ID: 7439 , actual: T1056 , predicted: T1056
# ID: 7441 , actual: T1027 , predicted: T1027
# ID: 7442 , actual: T1057 , predicted: T1057
# ID: 7443 , actual: T1090 , predicted: T1090
# ID: 7444 , actual: T1021 , predicted: T1219
# ID: 7446 , actual: T1518 , predicted: T1047
# ID: 7450 , actual: T1047 , predicted: T1047
# ID: 7454 , actual: T1140 , predicted: T1140
# ID: 7456 , actual: T1562 , predicted: T1112
# ID: 7479 , actual: T1070 , predicted: T1099
# ID: 7480 , actual: T1105 , predicted: T1105
# ID: 7497 , actual: T1106 , predicted: T1106
# ID: 7498 , actual: T1027 , predicted: T1027
# ID: 7503 , actual: T1082 , predicted: T1082
# ID: 7504 , actual: T1016 , predicted: T1016
# ID: 7505 , actual: T1033 , predicted: T1033
# ID: 7521 , actual: T1027 , predicted: T1027
# ID: 7525 , actual: T1016 , predicted: T1016
# ID: 7536 , actual: T1059 , predicted: T1106
# ID: 7537 , actual: T1005 , predicted: T1005
# ID: 7539 , actual: T1057 , predicted: T1057
# ID: 7549 , actual: T1553 , predicted: T1553
# ID: 7552 , actual: T1547 , predicted: T1112
# ID: 7556 , actual: T1106 , predicted: T1106
# ID: 7569 , actual: T1543 , predicted: T1050
# ID: 7570 , actual: T1140 , predicted: T1140
# ID: 7572 , actual: T1574 , predicted: T1073
# ID: 7581 , actual: T1105 , predicted: T1105
# ID: 7585 , actual: T1059 , predicted: T1055
# ID: 7586 , actual: T1564 , predicted: T1486
# ID: 7603 , actual: T1547 , predicted: T1112
# ID: 7613 , actual: T1560 , predicted: T1002
# ID: 7617 , actual: T1074 , predicted: T1002
# ID: 7618 , actual: T1573 , predicted: T1032
# ID: 7627 , actual: T1083 , predicted: T1083
# ID: 7634 , actual: T1078 , predicted: T1526
# ID: 7642 , actual: T1140 , predicted: T1140
# ID: 7651 , actual: T1027 , predicted: T1045
# ID: 7653 , actual: T1553 , predicted: T1116
# ID: 7658 , actual: T1071 , predicted: T1043
# ID: 7661 , actual: T1132 , predicted: T1132
# ID: 7664 , actual: T1036 , predicted: T1055
# ID: 7670 , actual: T1105 , predicted: T1105
# ID: 7679 , actual: T1132 , predicted: T1027
# ID: 7686 , actual: T1083 , predicted: T1083
# ID: 7687 , actual: T1564 , predicted: T1025
# ID: 7691 , actual: T1036 , predicted: T1036
# ID: 7701 , actual: T1560 , predicted: T1005
# ID: 7707 , actual: T1070 , predicted: T1070
# ID: 7710 , actual: T1547 , predicted: T1547
# ID: 7711 , actual: T1059 , predicted: T1059
# ID: 7714 , actual: T1083 , predicted: T1083
# ID: 7717 , actual: T1056 , predicted: T1056
# ID: 7730 , actual: T1547 , predicted: T1112
# ID: 7740 , actual: T1555 , predicted: T1555
# ID: 7741 , actual: T1140 , predicted: T1140
# ID: 7747 , actual: T1056 , predicted: T1010
# ID: 7750 , actual: T1057 , predicted: T1057
# ID: 7757 , actual: T1105 , predicted: T1105
# ID: 7760 , actual: T1027 , predicted: T1027
# ID: 7766 , actual: T1049 , predicted: T1049
# ID: 7767 , actual: T1102 , predicted: T1102
# ID: 7770 , actual: T1573 , predicted: T1027
# ID: 7771 , actual: T1083 , predicted: T1083
# ID: 7773 , actual: T1070 , predicted: T1099
# ID: 7784 , actual: T1059 , predicted: T1059
# ID: 7786 , actual: T1564 , predicted: T1055
# ID: 7790 , actual: T1027 , predicted: T1027
# ID: 7802 , actual: T1560 , predicted: T1560
# ID: 7803 , actual: T1547 , predicted: T1112
# ID: 7804 , actual: T1059 , predicted: T1064
# ID: 7808 , actual: T1056 , predicted: T1056
# ID: 7818 , actual: T1140 , predicted: T1140
# ID: 7821 , actual: T1083 , predicted: T1083
# ID: 7827 , actual: T1012 , predicted: T1012
# ID: 7831 , actual: T1016 , predicted: T1016
# ID: 7834 , actual: T1124 , predicted: T1124
# ID: 7840 , actual: T1057 , predicted: T1057
# ID: 7843 , actual: T1033 , predicted: T1033
# ID: 7846 , actual: T1547 , predicted: T1060
# ID: 7847 , actual: T1059 , predicted: T1059
# ID: 7853 , actual: T1105 , predicted: T1105
# ID: 7855 , actual: T1027 , predicted: T1027
# ID: 7856 , actual: T1113 , predicted: T1113
# ID: 7860 , actual: T1087 , predicted: T1033
# ID: 7868 , actual: T1562 , predicted: T1112
# ID: 7872 , actual: T1027 , predicted: T1027
# ID: 7881 , actual: T1016 , predicted: T1016
# ID: 7885 , actual: T1071 , predicted: T1043
# ID: 7895 , actual: T1140 , predicted: T1140
# ID: 7900 , actual: T1055 , predicted: T1055
# ID: 7907 , actual: T1102 , predicted: T1102
# ID: 7919 , actual: T1562 , predicted: T1562
# ID: 7922 , actual: T1070 , predicted: T1107
# ID: 7929 , actual: T1069 , predicted: T1069
# ID: 7934 , actual: T1021 , predicted: T1175
# ID: 7935 , actual: T1021 , predicted: T1570
# ID: 7936 , actual: T1018 , predicted: T1018
# ID: 7942 , actual: T1047 , predicted: T1047
# ID: 7948 , actual: T1057 , predicted: T1057
# ID: 7949 , actual: T1082 , predicted: T1082
# ID: 7951 , actual: T1070 , predicted: T1485
# ID: 7959 , actual: T1547 , predicted: T1112
# ID: 7960 , actual: T1547 , predicted: T1554
# ID: 7976 , actual: T1105 , predicted: T1105
# ID: 7977 , actual: T1056 , predicted: T1056
# ID: 7980 , actual: T1027 , predicted: T1027
# ID: 7985 , actual: T1021 , predicted: T1219
# ID: 7991 , actual: T1049 , predicted: T1049
# ID: 7992 , actual: T1569 , predicted: T1570
# ID: 7994 , actual: T1047 , predicted: T1047
# ID: 8006 , actual: T1036 , predicted: T1036
# ID: 8009 , actual: T1518 , predicted: T1082
# ID: 8012 , actual: T1497 , predicted: T1053
# ID: 8013 , actual: T1059 , predicted: T1059
# ID: 8015 , actual: T1059 , predicted: T1059
# ID: 8024 , actual: T1105 , predicted: T1105
# ID: 8026 , actual: T1106 , predicted: T1106
# ID: 8029 , actual: T1055 , predicted: T1055
# ID: 8038 , actual: T1106 , predicted: T1106
# ID: 8041 , actual: T1018 , predicted: T1018
# ID: 8048 , actual: T1547 , predicted: T1112
# ID: 8054 , actual: T1027 , predicted: T1045
# ID: 8056 , actual: T1012 , predicted: T1012
# ID: 8071 , actual: T1140 , predicted: T1140
# ID: 8072 , actual: T1041 , predicted: T1041
# ID: 8073 , actual: T1574 , predicted: T1073
# ID: 8078 , actual: T1027 , predicted: T1027
# ID: 8087 , actual: T1105 , predicted: T1105
# ID: 8091 , actual: T1055 , predicted: T1055
# ID: 8092 , actual: T1518 , predicted: T1063
# ID: 8105 , actual: T1016 , predicted: T1016
# ID: 8106 , actual: T1071 , predicted: T1071
# ID: 8109 , actual: T1083 , predicted: T1083
# ID: 8125 , actual: T1057 , predicted: T1057
# ID: 8127 , actual: T1113 , predicted: T1113
# ID: 8128 , actual: T1518 , predicted: T1518
# ID: 8139 , actual: T1566 , predicted: T1193
# ID: 8143 , actual: T1204 , predicted: T1221
# ID: 8147 , actual: T1518 , predicted: T1016
# ID: 8169 , actual: T1055 , predicted: T1055
# ID: 8170 , actual: T1090 , predicted: T1090
# ID: 8174 , actual: T1049 , predicted: T1049
# ID: 8177 , actual: T1132 , predicted: T1027
# ID: 8185 , actual: T1071 , predicted: T1197
# ID: 8190 , actual: T1059 , predicted: T1064
# ID: 8192 , actual: T1041 , predicted: T1041
# ID: 8194 , actual: T1056 , predicted: T1056
# ID: 8214 , actual: T1003 , predicted: T1003
# ID: 8215 , actual: T1021 , predicted: T1076
# ID: 8236 , actual: T1560 , predicted: T1560
# ID: 8241 , actual: T1555 , predicted: T1555
# ID: 8250 , actual: T1003 , predicted: T1555
# ID: 8256 , actual: T1082 , predicted: T1082
# ID: 8257 , actual: T1016 , predicted: T1016
# ID: 8269 , actual: T1112 , predicted: T1112
# ID: 8276 , actual: T1071 , predicted: T1071
# ID: 8283 , actual: T1105 , predicted: T1105
# ID: 8304 , actual: T1057 , predicted: T1057
# ID: 8309 , actual: T1547 , predicted: T1112
# ID: 8316 , actual: T1082 , predicted: T1082
# ID: 8322 , actual: T1059 , predicted: T1059
# ID: 8323 , actual: T1132 , predicted: T1132
# ID: 8330 , actual: T1105 , predicted: T1105
# ID: 8335 , actual: T1087 , predicted: T1033
# ID: 8342 , actual: T1005 , predicted: T1005
# ID: 8348 , actual: T1016 , predicted: T1016
# ID: 8349 , actual: T1204 , predicted: T1193
# ID: 8352 , actual: T1059 , predicted: T1105
# ID: 8356 , actual: T1053 , predicted: T1053
# ID: 8357 , actual: T1204 , predicted: T1193
# ID: 8358 , actual: T1573 , predicted: T1032
# ID: 8369 , actual: T1562 , predicted: T1090
# ID: 8370 , actual: T1070 , predicted: T1485
# ID: 8382 , actual: T1059 , predicted: T1059
# ID: 8386 , actual: T1057 , predicted: T1057
# ID: 8387 , actual: T1087 , predicted: T1087

# %%
print("len(test)            =", len(test))
print("len(predicted_labels) =", len(predicted_labels))
# 予測結果をDataFrameに追加
test["Predicted"] = predicted_labels

# CSVとして保存
test.to_csv("DSAサブテクニック削除版.csv", index=False, encoding="utf-8")
# Out:
# len(test)            = 1678
# len(predicted_labels) = 1678

# %%
print(test.columns)
# Out:
# Index(['ID', 'test_or_train', 'act_Technique ID', 'act_Technique Name',
#        'act_TacticsName', 'Sentences', 'Predicted_TacticsName', 'Predicted'],
#       dtype='object')

# %% [markdown]
# ### Evaluate

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 正解ラベル（ATT&CK Technique ID）
y_true = test["act_Technique ID"].values

# 予測ラベル（Llama の出力）
# predicted_labels は Llama 推論ループで append していたリスト
y_pred = predicted_labels

# ---- 評価 ----
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print(f"Accuracy:  {accuracy}")
print(f"Precision: {precision}")
print(f"Recall:    {recall}")
print(f"F1 Score:  {f1}")
# Out:
# Accuracy:  0.5953516090584029
# Precision: 0.8129904697792738
# Recall:    0.5953516090584029
# F1 Score:  0.6137735229492881

# %%
# import pandas as pd

# # ① CSV を読み込み
# df_base = pd.read_csv("/workspace/miluser/Mitsuharu_2002/csv_data/TTPHunter_dataset.csv")              # Domain, Technique ID, Technique Name, Sentences
# df_pred = pd.read_csv("/workspace/miluser/Mitsuharu_2002/predicted_Tactics_70B_1678.csv")     # Technique ID, Tactics Name, Sentences, Predicted

# # （もし念のためヘッダに余計な空白がありそうなら）
# df_base.columns = df_base.columns.str.strip()
# df_pred.columns = df_pred.columns.str.strip()

# # ② Predicted だけ使う（＋キーになる Sentences）
# df_pred_small = df_pred[["Sentences", "Predicted"]]

# # ③ Sentences をキーに結合（LEFT JOIN）
# df_merged = df_base.merge(df_pred_small, on="Sentences", how="left")

# # ④ 保存
# df_merged.to_csv("TTPHunter_with_Predicted.csv", index=False)

# %%
["\nClassification:"+str(score)+"\n" for doc, score in search_results]

# %% [markdown]
# 以下追加分（混合行列）

# %%
import sys
print(sys.executable)

# !pip install --upgrade pip

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_true, y_pred, labels=sorted(list(set(y_true))))
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=False, cmap="Blues", xticklabels=True, yticklabels=True)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

import pandas as pd

print(pd.Series(y_pred).value_counts())

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# ラベルを揃えておく
labels = sorted(list(set(y_true)))

cm = confusion_matrix(y_true, y_pred, labels=labels)

plt.figure(figsize=(12, 10))
sns.heatmap(
    cm,
    annot=True,      # ★ 数字を表示
    fmt="d",         # ★ 整数表示（floatなら ".2f" とか）
    cmap="Blues",
    xticklabels=labels,
    yticklabels=labels
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

print(pd.Series(y_pred).value_counts())

# %%
for t,p,txt in zip(y_true, y_pred, test["text"]):
    if t != p:
        print("True:", t)
        print("Pred:", p)
        print("Text:", txt)
        print("-" * 50)

# %% [markdown]
# ### Few Shot learning 2

# %%
# Aggregate predictions using majority voting
from collections import Counter

def majority_voting(predictions):
    count = Counter(predictions)
    return count.most_common(1)[0][0]

# %%
import random

def create_prompt(template, search_results, text_to_predict):
    xs = ["\nText:"+ doc.page_content.lower()+"\nClassification:"+doc.metadata['TTP_ID'] for doc, _ in search_results]
    xs = ''.join(xs)+"\nText:"+ text_to_predict.lower() +"\nClassification:"
    return template + xs

def split_list(lst):
    random.shuffle(lst)  # Shuffle the list to ensure randomness
    n = len(lst)
    third = n // 3
    remainder = n % 3

    # Determine the splitting points
    split1 = third
    split2 = third * 2

    if remainder == 1:
        split1 += 1
    elif remainder == 2:
        split1 += 1
        split2 += 1

    # Split the list
    first_third = lst[:split1]
    second_third = lst[split1:split2]
    third_third = lst[split2:]

    return first_third, second_third, third_third



predicted_labels = []
# Iterating over the DataFrame row by row
for index, row in test.iterrows():
    #print(f"Index: {index}")
    text_to_predict = row["Sentences"]

    search_results = db.similarity_search_with_score(text_to_predict, k=150)

    template1 = "Your task is to classify the last sentence of 'Text' based on the provided examples. Each example shows a sentence and its corresponding classification label. Use these examples to determine the correct classification for the given text. Return only the classification label starting with 'T'.\n"
    template2 = "Please classify the last sentence of 'Text' based on the provided examples. Each example shows a sentence and its classification label. Use the patterns from these examples to classify the given text correctly. Return only the classification label starting with 'T'.\n"
    template3 = "Your task is to determine the classification of the last sentence of 'Text' using the provided examples. Each example pairs a sentence with its classification label. Analyze these examples to classify the given text. Output only the classification label starting with 'T'.\n"

    ## Split the list
    first_part, second_part, third_part = split_list(search_results)

    
    prompt1 = create_prompt(template1, first_part, text_to_predict)
    prompt2 = create_prompt(template2, second_part, text_to_predict)
    prompt3 = create_prompt(template3, third_part, text_to_predict)
    
    # Collect predictions
    prompts = [prompt1, prompt2, prompt3]
    predictions = []
    
    for prompt in prompts:
        
        prediction = llm.invoke(prompt).content
        predictions.append(prediction)

    print(predictions)
    
    
    final_prediction = majority_voting(predictions)
    #print("Final Prediction:", final_prediction)
    predicted_labels.append(final_prediction)
    print("actual:", row["Technique ID"], ", predicted:", final_prediction)

# %% [markdown]
# ### Evaluate

# %%
cleaned_labels = [label.replace('Classification:', '') for label in predicted_labels]

# Example vectors containing strings
y_true = test["Technique ID"].values#["cat", "dog", "fish", "cat", "dog"]
#y_true = train_data.Key
y_pred = cleaned_labels#.values#["cat", "dog", "cat", "cat", "dog"]

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='weighted')
print(f"Precision: {precision}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='weighted')
print(f"Recall: {recall}")

# Calculate F1 score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"F1 Score: {f1}")

# %% [markdown]
# temperature:0, k=45
#
# Accuracy: 0.9523809523809523
# Precision: 0.9761904761904762
# Recall: 0.9523809523809523
# F1 Score: 0.9603174603174602
#
# temperature:1, k=45
#
# Accuracy: 0.9285714285714286
# Precision: 0.9642857142857143
# Recall: 0.9285714285714286
# F1 Score: 0.9365079365079364

# %% [markdown]
# ### V2 - SecureBERT Embeddings

# %%
### embedding
model2 = "ehsanaghaei/SecureBERT"
embeddings2 = HuggingFaceEmbeddings(model_name = model2)

docs2 = []
for index, row in train.iterrows():
    doc = Document(page_content=row["Sentences"], metadata={"TTP_ID": row["Technique ID"]})
    docs2.append(doc)

print(len(docs2))

# %%
db2 = FAISS.from_documents(docs2, embeddings2)

# %%
from langchain_openai import OpenAIEmbeddings

embeddings3 = OpenAIEmbeddings(
    model="text-embedding-3-large",
    # With the `text-embedding-3` class
    # of models, you can specify the size
    # of the embeddings you want returned.
    # dimensions=1024
)

db3 = FAISS.from_documents(docs2, embeddings3)

# %%
db2

# %%
from langchain_openai import ChatOpenAI

# Choose the LLM that will drive the agent
llm = ChatOpenAI(model="gpt-4o", temperature=0)###, model_kwargs={"top_p": 0.0})
#llm = ChatOpenAI(model="o1-mini", temperature=1)
#llm = ChatOpenAI(model="chatgpt-4o-latest", temperature=0)

#llm.invoke(prompt)

scores_list = []
predicted_labels = []
# Iterating over the DataFrame row by row
for index, row in test.iterrows():
    #print(f"Index: {index}")
    text_to_predict = row["Sentences"]

    ##### Prompt 1
    search_results = db3.similarity_search_with_score(text_to_predict, k=45)

    
    xs = ["\nText:"+ doc.page_content.lower().strip()+"\nSimilarity:"+ str(score) +"\nClassification:"+doc.metadata['TTP_ID']+"\n" for doc, score in search_results if score < 2]
    #xs = ["\nText:'"+ doc.page_content.lower().strip()+"'\nSimilarity:"+ str(score) +"\nClassification:"+doc.metadata['TTP_ID']+"\n" for doc, score in search_results]
    

    xs = ''.join(xs)+"\nInputText:"+ text_to_predict.lower().strip() +"\nClassification:"
    xs = "Your task is to classify the last sentence of 'InputText' based on the provided examples. Each example shows a sentence, inverse similarity to InputText (the lower the better), and its corresponding classification label. Use these examples to determine the correct classification for the given text. Return only the classification label starting with 'T'.\n" + xs
    #xs = "You are an expert in text classification. Below are examples of texts with their classifications based on their similarity to the 'InputText'. For the 'InputText' provided, choose the most appropriate classification based on the examples given. Only return the classification label (e.g., TXXXX). Use the closest similarity as the primary criterion for classification.\n\n" + xs
    #####
    [scores_list.append(score) for doc, score in search_results]
    ### search
    '''
    search_results = db.similarity_search_with_score(text_to_predict, k=55)
    xs = ["\n"+ "Example "+ str(i) +":\nText:"+ doc.page_content.lower()+"\nClassification:"+doc.metadata['TTP_ID']+"\n" for i, (doc, _) in enumerate(search_results)]
    ##xs = ["\nText:"+" ".join(str(doc.page_content).lower().split())+"\nClassification:"+doc.metadata['TTP_ID'] for doc, _ in search_results]
    

    ### mmr search
    #search_results = db.max_marginal_relevance_search(text_to_predict,k=45, fetch_k=250)
    #xs = ["\nText:"+doc.page_content.lower()+"\nClassification:"+doc.metadata['TTP_ID'] for doc in search_results]

    
    xs += "\n\nNote: The examples show a pattern where certain attack behaviors correspond to specific classification labels. Use this pattern recognition to classify the new text accurately.\nNow, classify the following text:\n"
    xs = ''.join(xs)+"\nText:"+ text_to_predict.lower() +"\nClassification:"
    #xs = "Your task is to classify the last sentence of 'Text' based on the provided examples. Each example shows a sentence and its corresponding classification label. Use these examples to determine the correct classification for the given text. Return only the classification label starting with 'T'.\n" + xs
    xs = "Your task is to classify the last sentence of 'Text' based on the diverse examples provided below. Learn the patterns from these examples to make accurate classifications. Output only the classification label beginning with 'T'.\n\nExamples:\n" + xs
    '''
    #print(xs)
    prompt = xs#prompt#"Write a poem about a cat chasing a butterfly."
    result = llm.invoke(prompt)
    predicted_label = result.content
    
    #predicted_label = most_common_ttp_id
    #print(predicted_label)
    predicted_labels.append(predicted_label)
    print("actual:", row["Technique ID"], ", predicted:", predicted_label)
    #break

# %% [markdown]
# ### No LLM Call

# %%
from langchain_openai import ChatOpenAI

# Choose the LLM that will drive the agent
llm = ChatOpenAI(model="gpt-4o", temperature=0)###, model_kwargs={"top_p": 0.0})
#llm = ChatOpenAI(model="chatgpt-4o-latest", temperature=0)

#llm.invoke(prompt)

scores_list = []
predicted_labels = []
# Iterating over the DataFrame row by row
for index, row in test.iterrows():
    #print(f"Index: {index}")
    text_to_predict = row["Sentences"]

    ##### Prompt 1
    search_results = db2.similarity_search_with_score(text_to_predict, k=45)

    
    xs = ["\nText:"+ doc.page_content.lower().strip()+"\nSimilarity:"+ str(score) +"\nClassification:"+doc.metadata['TTP_ID']+"\n" for doc, score in search_results if score < 2]
    #xs = ["\nText:'"+ doc.page_content.lower().strip()+"'\nSimilarity:"+ str(score) +"\nClassification:"+doc.metadata['TTP_ID']+"\n" for doc, score in search_results]
    

    xs = ''.join(xs)+"\nInputText:"+ text_to_predict.lower().strip() +"\nClassification:"
    xs = "Your task is to classify the last sentence of 'InputText' based on the provided examples. Each example shows a sentence, inverse similarity to InputText (the lower the better), and its corresponding classification label. Use these examples to determine the correct classification for the given text. Return only the classification label starting with 'T'.\n" + xs
    #xs = "You are an expert in text classification. Below are examples of texts with their classifications based on their similarity to the 'InputText'. For the 'InputText' provided, choose the most appropriate classification based on the examples given. Only return the classification label (e.g., TXXXX). Use the closest similarity as the primary criterion for classification.\n\n" + xs
    #####
    [scores_list.append(score) for doc, score in search_results]
    
    #print(xs)
    #prompt = xs#prompt#"Write a poem about a cat chasing a butterfly."
    #result = llm.invoke(prompt)
    #predicted_label = result.content
    
    #predicted_label = most_common_ttp_id
    #print(predicted_label)
    #predicted_labels.append(predicted_label)
    #print("actual:", row["Technique ID"], ", predicted:", predicted_label)
    #break

# %%
### Evaluate

# %%
cleaned_labels = [label.replace('Classification:', '') for label in predicted_labels]

# Example vectors containing strings
y_true = test["Technique ID"].values#["cat", "dog", "fish", "cat", "dog"]
#y_true = train_data.Key
y_pred = cleaned_labels#.values#["cat", "dog", "cat", "cat", "dog"]

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='weighted')
print(f"Precision: {precision}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='weighted')
print(f"Recall: {recall}")

# Calculate F1 score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"F1 Score: {f1}")

# %%
# Secure Bert Embeddings - 
Accuracy: 0.9523809523809523
Precision: 0.9880952380952381
Recall: 0.9523809523809523
F1 Score: 0.9619047619047618

# %%
from statistics import mean
print(max(scores_list))
print(mean(scores_list))
print(min(scores_list))

# %%
from statistics import mean
print(max(scores_list))
print(mean(scores_list))
print(min(scores_list))

# %%
# Find incorrectly classified labels
incorrect_classifications = []
for index, (true_label, pred_label) in enumerate(zip(y_true, y_pred)):
    if true_label != pred_label:
        incorrect_classifications.append({
            'Index': index,
            'True Label': true_label,
            'Predicted Label': pred_label
        })

# Output the results
if incorrect_classifications:
    print("Incorrectly Classified Labels:")
    for item in incorrect_classifications:
        print(f"Index {item['Index']}: True Label = {item['True Label']}, Predicted Label = {item['Predicted Label']}")
else:
    print("All labels are correctly classified.")

# %%
print(xs)

# %%
train["Technique ID"].value_counts()["T1036"]#.head()

# %% [markdown]
# ### SImilarity Investigation

# %%
score_list = []
very_similar_string = "kerrdown can use a vbs base64 decoder function published by motobit"
totaly_wrong_string = "we have a nice weather today"
search_results2 = db2.similarity_search_with_score(very_similar_string, k=45)
[score_list.append(score) for doc, score in search_results2]
["\nText:"+ doc.page_content.lower().strip()+"\nSimilarity:"+ str(score) +"\nClassification:"+doc.metadata['TTP_ID']+"\n" for doc, score in search_results2 if score < 2]
#score_list

# %% [markdown]
# ### V3

# %%
# Choose the LLM that will drive the agent
llm = ChatOpenAI(model="gpt-4o", temperature=0)###, model_kwargs={"top_p": 0.0})
#llm = ChatOpenAI(model="chatgpt-4o-latest", temperature=0)

#llm.invoke(prompt)

def predict_label(text_to_predict):
    ##### Prompt 1
    search_results = db2.similarity_search_with_score(text_to_predict, k=45)

    
    xs = ["\nText:"+ doc.page_content.lower().strip()+"\nSimilarity:"+ str(score) +"\nClassification:"+doc.metadata['TTP_ID']+"\n" for doc, score in search_results if score < 2]
    #xs = ["\nText:'"+ doc.page_content.lower().strip()+"'\nSimilarity:"+ str(score) +"\nClassification:"+doc.metadata['TTP_ID']+"\n" for doc, score in search_results]
    

    xs = ''.join(xs)+"\nInputText:"+ text_to_predict.lower().strip() +"\nClassification:"
    xs = """You are a MITRE ATT&CK TTP classification expert.
    Your task is to classify the 'InputText' based on the provided examples below.
    Each example shows a sentence, inverse similarity to InputText (the lower the better),
    and its corresponding classification label starting with 'T'.
    Use these examples to determine the correct classification for the given text (InputText).
    If 'InputText' is completely not related to any of the provided examples, return class 'T0000'.
    To determine if the 'InputText' is not related to the given examples, you can use the 'Similarity' propery of the examples.
    Low 'Similarity' values indicate the high similarity in strings.
    Return only the classification label starting with 'T' or 'T0000' if you found no appropriate class for 'InputText'.\n""" + xs
    #xs = "You are an expert in text classification. Below are examples of texts with their classifications based on their similarity to the 'InputText'. For the 'InputText' provided, choose the most appropriate classification based on the examples given. Only return the classification label (e.g., TXXXX). Use the closest similarity as the primary criterion for classification.\n\n" + xs
    #####
    
    #print(xs)
    prompt = xs#prompt#"Write a poem about a cat chasing a butterfly."
    result = llm.invoke(prompt)
    predicted_label = result.content
    return predicted_label


scores_list = []
predicted_labels = []
# Iterating over the DataFrame row by row
for index, row in test.iterrows():
    #print(f"Index: {index}")
    text_to_predict = row["Sentences"]

    predicted_label = predict_label(text_to_predict)
    
    #predicted_label = most_common_ttp_id
    #print(predicted_label)
    predicted_labels.append(predicted_label)
    print("actual:", row["Technique ID"], ", predicted:", predicted_label)
    #break

# %%
print(xs)

# %%
cleaned_labels = [label.replace('Classification:', '') for label in predicted_labels]

# Example vectors containing strings
y_true = test["Technique ID"].values#["cat", "dog", "fish", "cat", "dog"]
#y_true = train_data.Key
y_pred = cleaned_labels#.values#["cat", "dog", "cat", "cat", "dog"]

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='weighted')
print(f"Precision: {precision}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='weighted')
print(f"Recall: {recall}")

# Calculate F1 score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"F1 Score: {f1}")

# %%
predict_label("We have a beautiful wether today")

# %% [markdown]
# ### Text to Predict

# %%
text_to_predict = """
sofacy uses dealerschoice to target european government agency
robert falcone	by robert falcone
march 15, 2018 at 1:00 pm
category: unit 42 tags: dealerschoice, european government agency, sofacy summary back in october 2016, unit 42 published an initial analysis on a flash exploitation framework used by the sofacy threat group called dealerschoice. the attack consisted of microsoft word delivery documents that contained adobe flash objects capable of loading additional malicious flash objects embedded in the file or directly provided by a command and control server. sofacy continued to use dealerschoice throughout the fall of 2016, which we also documented in our december 2016 publication discussing sofacy s larger campaign. on march 12 and march 14, we observed the sofacy group carrying out an attack on a european government agency involving an updated variant of dealerschoice. the updated dealerschoice documents used a similar process to obtain a malicious flash object from a c2 server, but the inner mechanics of the flash object contained significant differences in comparison to the original samples we analyzed. one of the differences was a particularly clever evasion technique: to our knowledge this has never been observed in use. with the previous iterations of dealerschoice samples, the flash object would immediately load and begin malicious tasks. in the march attacks, the flash object is only loaded if the user scrolls through the entire content of the delivery document and views the specific page the flash object is embedded on. also, dealerschoice requires multiple interactions with an active c2 server to successfully exploit an end system. the overall process to result in a successful exploitation is: user must open the microsoft word email attachment
user must scroll to page three of the document, which will run the dealerschoice flash object
the flash object must contact an active c2 server to download an additional flash object containing exploit code
the initial flash object must contact the same c2 server to download a secondary payload
victim host must have a vulnerable version of flash installed the attack the attack involving this updated variant of dealerschoice was targeting a european government organization. the attack relied on a spear-phishing email with a subject of defence & security 2018 conference agenda that had an attachment with a filename of defence & security 2018 conference . the attached document contains a conference agenda that the sofacy group appears to have copied directly from the website for the underwater defence & security 2018 conference here. opening the attached defence & security 2018 conference file does not immediately run malicious code to exploit the system. instead, the user must scroll to the third page of the document, which will load a flash object that contains actionscript that will attempt to exploit the user s system to install a malicious payload. the flash object embedded within this delivery document is a variant of an exploit tool that we call dealerschoice. this suggests that the sofacy group is confident that the targeted individuals would be interested enough in the content to peruse through it. we analyzed the document to determine the reason that the malicious flash object only ran when the user scrolled to the third page. according to the file, the dealerschoice loader swf exists after the covert-shores- image file within the delivery document. this image file exists on the third page of the document, so the user would have to scroll down in the document to this third page to get the swf file to run. the user may not notice the flash object on the page, as word displays it as a tiny black box in the document, as seen in figure 1. this is an interesting anti-sandbox technique, as it requires human interaction prior to the document exhibiting any malicious activity. updated dealerschoice this dealerschoice flash object shares a similar process to previous variants; however, it appears that the sofacy actors have made slight changes to its internal code. also, it appears that the actors used actionscript from an open source video player called f4player , which is freely available on github with the following description: f4player is an open source flash (as3) video player and library project. it is so small that it is only 10kb (with skin file) and totally free under gpl license. the sofacy developer modified the f4player s actionscript to include additional code to load an embedded flash object. the additions include code to decrypt an embedded flash object and an event handler that calls a newly added function ( skinevent2 ) that plays the decrypted object, as seen in the code snippet below: the above code allows dealerschoice to load a second swf object, specifically loading it with an argument that includes a c2 url of hxxp://ndpmedia24[.]com/0pq6m4f.m3u8 . the embedded swf extracts the domain from the c2 url passed to it and uses it to craft a url to get the server s file in order to obtain permissions to load additional flash objects from the c2 domain. the actionscript relies on event listeners to call specific functions when the event event.complete is triggered after successful http requests are issued to the c2 server. the event handlers call functions with the following names, which includes an incrementing number that represents the order in which the functions are called: with these event handlers created, the actionscript starts by gathering system data from the flash.system.capabilities.serverstring property (just like in the original samples) and issues an http get with the system data as a parameter to the c2 url that was passed as an argument to the embedded swf when it was initially loaded. when this http request completes, the event listener will call the onload1 function. the onload1 function parses the response data from the request to the c2 url using regular expressions. according to the following code snippet, it appears the regular expression is looking for a hexadecimal string after / and before /sec , as well as any string between /hls/ and /tracks : the regular expressions suggest that the c2 server responds with content that is meant to resemble http live steaming (hls) traffic, which is a protocol that uses http to deliver audio and video files for streaming. the use of hls coincides with the use of actionscript code from the f4player to make the traffic seem legitimate. the variables storing the results of the regular expression matches are used within the actionscript for further interaction with the c2 server. the following is a list of these variables and their purpose: the onload1 function then sends an http get request to the c2 domain using the value stored in the r3 variable as a url. when this http request completes, the event listener will call the onload2 function. the onload2 function decrypts the response received from the http request issued in onload1 function. it does so by calling a sub-function to decrypt the content, using the value stored in the r1 variable as a key. the sub-function to decrypt the content skips the first 4 bytes, suggesting that the first four bytes of the downloaded content is in cleartext (most likely the fws or cws header to look legitimate). after decrypting the content, the onload2 function will issue another http get request with the system data as a parameter, but this time to the c2 using a url from the r4 variable. when this request completes, the event listener will call the onload3 function. the onload3 function will take the response to the http request in onload2 and treat it as the payload. the actionscript will read each byte of the c2 response and get the hexadecimal value of each byte and create a text array of 4-byte hexadecimal values with 0x prepended and , appended to each using the following code: this hexadecimal string will most likely be a string of shellcode that will contain and decrypt the ultimate portable executable (pe) payload. the string of comma separated hexadecimal values is passed as a parameter when loading the swf file downloaded in onload2 . this function creates an event listener for when the swf file is successfully loaded, which will call the onload5 function. the onload5 function is responsible for adding the newly loaded swf object as a child object to the current running object using the following code: this loads the swf file, effectively running the malicious code on the system. during our analysis, we were unable to coerce the c2 into providing a malicious swf or payload. as mentioned in our previous blogs on dealerschoice, the payload of choice for previous variants was sofacycarberp (seduploader), but we have no evidence to suggest this tool was used in this attack. we are actively researching and will update this blog in the event we discover the malicious flash object and payload delivered in this attack. linkage to prior campaign the delivery document used in this attack was last modified by a user named nick daemoji , which provides a linkage to previous sofacy related delivery documents. the previous documents that used this user name were macro-laden delivery documents that installed sofacycarberp/seduploader payloads, as discussed in talos blog. this overlap also points to a similar social engineering theme between these two campaigns, as both used content from upcoming military and defense conferences as a lure. conclusion the sofacy threat group continues to use their dealerschoice framework to exploit flash vulnerabilities in their attack campaigns. in the most recent variant, sofacy modified the internals of the malicious scripts, but continues to follow the same process used by previous variants by obtaining a malicious flash object and payload directly from the c2 server. unlike previous samples, this dealerschoice used a docx delivery document that required the user to scroll through the document to trigger the malicious flash object. the required user interaction turned out to be an interesting anti-sandbox technique that we had not seen this group perform in the past.
"""

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

text = "Hello world. How are you? I'm doing great!"
sentences = sent_tokenize(text)

print(sentences)

# %%
###
text_sentences = sent_tokenize(text_to_predict)

text_ttps = []
for sentence in text_sentences:
    text_ttp = predict_label(sentence)
    print(sentence, " ->", text_ttp, "\n---")
    text_ttps.append(text_ttp)

# %%
set(text_ttps)

# %%
### 
predict_label("Process Hashes and Process Privilege Checks Upon being loaded, the malware starts a subroutine that hashes each running process on the system, and compares each hash with 3 hardcoded hashes: 0x6403527E → avp.exe associated with Kaspersky AV 0x23214B44 → ns.exe associated with Norton Security 0x651B3005 → ccSvcHst.exe associated with Symantec A global flag PROC_FLAG is used to track which of the 3 processes are running on the system. PROC_FLAG")

# %%
predict_label("PROC_FLAG")

# %% [markdown]
# ### V4 - DB Index Optimization

# %%
import faiss
import numpy as np
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.cluster import KMeans

# Load SecureBERT
tokenizer = AutoTokenizer.from_pretrained(model2)
model = AutoModel.from_pretrained(model2)

# Move model to GPU if available, otherwise use CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Function to generate SecureBERT embeddings for a single text
def get_embedding(text):
    tokens = tokenizer(text, padding=True, truncation=True, return_tensors='pt').to(device)
    with torch.no_grad():
        outputs = model(**tokens)
    # Pool the last hidden state to get sentence embedding
    embedding = outputs.last_hidden_state.mean(dim=1).cpu().numpy()  # Move embedding to CPU
    return embedding

# Extract texts and labels
texts = list(train["Sentences"].values)  # List of text items
labels = list(train["Technique ID"].values)  # List of labels

# Get SecureBERT embeddings for each document, item by item
embeddings = []

for text in texts:
    embedding = get_embedding(text)
    embeddings.append(embedding)

# Convert list of embeddings to a numpy array
embeddings = np.vstack(embeddings)  # Stack embeddings vertically to create a single array

# Normalize embeddings (L2 normalization)
embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

# %%
# Normalize embeddings (L2 normalization)
embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

# Supervised clustering using labels

# Get unique labels
unique_labels = set(labels)
n_classes = len(set(labels))
label_embeddings = {label: [] for label in unique_labels}

# Group embeddings by label
for embedding, label in zip(embeddings, labels):
    label_embeddings[label].append(embedding)

# Create label-guided centroids using KMeans for each class
centroids = []
for label, emb_list in label_embeddings.items():
    emb_array = np.array(emb_list)
    if len(emb_list) > 1:
        # Use KMeans to create centroids for each class, useful if there are multiple samples per class
        kmeans = KMeans(n_clusters=1, random_state=42)
        kmeans.fit(emb_array)
        centroids.append(kmeans.cluster_centers_[0])
    else:
        # If only one sample, use it directly as the centroid
        centroids.append(emb_array[0])

# Convert centroids to a numpy array
centroids = np.array(centroids)

# Initialize FAISS Index
d = embeddings.shape[1]  # dimension of the embeddings
nlist = n_classes  # number of clusters, one per class

#quantizer = faiss.IndexFlatL2(d)  # the quantizer used for clustering
#index = faiss.IndexIVFFlat(quantizer, d, nlist, faiss.METRIC_L2)

index = faiss.IndexFlatL2(d)

# Train the FAISS index with the supervised centroids
#index.train(centroids)
#index.train(embeddings)
# Add embeddings to the index
index.add(embeddings)

# %%
centroids

# %%
# Example query


query_texts = ["Search the document with relevant content."]
query_embeddings = get_embedding(query_texts)
query_embeddings = query_embeddings / np.linalg.norm(query_embeddings, axis=1, keepdims=True)

# Perform search
k = 45  # number of nearest neighbors
distances, indices = index.search(query_embeddings, k)

print(distances)

'''
# Print the search results
for i, query in enumerate(query_texts):
    print(f"Query: {query}")
    for j in range(k):
        if indices[i][j] != -1:  # valid index check
            print(f"Neighbor {j+1}: Document: {documents[indices[i][j]]['text']}, Distance: {distances[i][j]}")
'''

# %%
llm = ChatOpenAI(model="gpt-4o", temperature=0)###, model_kwargs={"top_p": 0.0})
predicted_labels = []
scores_list = []
for i, row in test.iterrows():
    #print(f"Index: {index}")
    text_to_predict = row["Sentences"]

    query_texts = text_to_predict#["Search the document with relevant content."]
    query_embeddings = get_embedding(query_texts)
    query_embeddings = query_embeddings / np.linalg.norm(query_embeddings, axis=1, keepdims=True)
    
    # Perform search
    k = 60  # number of nearest neighbors
    distances, indices = index.search(query_embeddings, k)

    retrieved_docs = [texts[i] for i in indices[0] if i != -1]
    retrieved_labels = [labels[i] for i in indices[0] if i != -1]


    
    #[print(doc, score, label) for doc, score, label in zip(retrieved_docs, distances, labels) if score < 2]
    
    xs = ["\nText:"+ doc.lower().strip()+"\nSimilarity:"+ str(score) +"\nClassification:"+label+"\n" for doc, score, label in zip(retrieved_docs, distances.flatten(), retrieved_labels) if score < 2]
    #xs = ["\nText:'"+ doc.page_content.lower().strip()+"'\nSimilarity:"+ str(score) +"\nClassification:"+doc.metadata['TTP_ID']+"\n" for doc, score in search_results]
    

    xs = ''.join(xs)+"\nInputText:"+ text_to_predict.lower().strip() +"\nClassification:"
    xs = "Your task is to classify the last sentence of 'InputText' based on the provided examples. Each example shows a sentence, inverse similarity to InputText (the lower the better), and its corresponding classification label. Use these examples to determine the correct classification for the given text. Return only the classification label starting with 'T'.\n" + xs
    
    #####
    
    #print(xs)
    prompt = xs#prompt#"Write a poem about a cat chasing a butterfly."
    result = llm.invoke(prompt)
    predicted_label = result.content

    predicted_labels.append(predicted_label)
    print("actual:", row["Technique ID"], ", predicted:", predicted_label)
    
    
    #print(distances)
    #print("----")
   
    [scores_list.append(score) for score in distances.flatten()]

# %%
cleaned_labels = [label.replace('Classification:', '') for label in predicted_labels]

# Example vectors containing strings
y_true = test["Technique ID"].values#["cat", "dog", "fish", "cat", "dog"]
#y_true = train_data.Key
y_pred = cleaned_labels#.values#["cat", "dog", "cat", "cat", "dog"]

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy}")

# Calculate precision
precision = precision_score(y_true, y_pred, average='weighted')
print(f"Precision: {precision}")

# Calculate recall
recall = recall_score(y_true, y_pred, average='weighted')
print(f"Recall: {recall}")

# Calculate F1 score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"F1 Score: {f1}")

# %%
#scores_list

# %%
from statistics import mean
print(max(scores_list))
print(mean(scores_list))
print(min(scores_list))

# %%
len(retrieved_docs)
